# %% [markdown]
# # Analyzing Startup Fundraising Deals from Crunchbase
#
#
# The data set of investments we'll be exploring is current as of October 2013.

# %%
import numpy as np
import pandas as pd

first_five = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1').head()
first_five
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      company_permalink company_name company_category_code  \
# 0    /company/advercar     AdverCar           advertising
# 1  /company/launchgram   LaunchGram                  news
# 2        /company/utap         uTaP             messaging
# 3    /company/zoopshop     ZoopShop              software
# 4    /company/efuneral     eFuneral                   web
#
#   company_country_code company_state_code         company_region  \
# 0                  USA                 CA                 SF Bay
# 1                  USA                 CA                 SF Bay
# 2                  USA                NaN  United States - Other
# 3                  USA                 OH               Columbus
# 4                  USA                 OH              Cleveland
#
#     company_city          investor_permalink      investor_name  \
# 0  San Francisco  /company/1-800-flowers-com  1-800-FLOWERS.COM
# 1  Mountain View        /company/10xelerator        10Xelerator
# 2            NaN        /company/10xelerator        10Xelerator
# 3       columbus        /company/10xelerator        10Xelerator
# 4      Cleveland        /company/10xelerator        10Xelerator
#
#   investor_category_code investor_country_code investor_state_code  \
# 0                    NaN                   USA                  NY
# 1                finance                   USA                  OH
# 2                finance                   USA                  OH
# 3                finance                   USA                  OH
# 4                finance                   USA                  OH
#
#   investor_region investor_city funding_round_type   funded_at funded_month  \
# 0        New York      New York           series-a  2012-10-30      2012-10
# 1        Columbus      Columbus              other  2012-01-23      2012-01
# 2        Columbus      Columbus              other  2012-01-01      2012-01
# 3        Columbus      Columbus              angel  2012-02-15      2012-02
# 4        Columbus      Columbus              other  2011-09-08      2011-09
#
#   funded_quarter  funded_year  raised_amount_usd
# 0        2012-Q4       2012.0          2000000.0
# 1        2012-Q1       2012.0            20000.0
# 2        2012-Q1       2012.0            20000.0
# 3        2012-Q1       2012.0            20000.0
# 4        2011-Q3       2011.0            20000.0

# %%
# Chunking 5000 rows

chunking = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1', chunksize=5000)
chunk_mem = []
for chunk in chunking:
    chunk_mem.append(chunk.memory_usage(deep=True).sum() / 2**20)
    
chunk_mem
# Out:
# [5.579195022583008,
#  5.528186798095703,
#  5.535004615783691,
#  5.528162956237793,
#  5.5243072509765625,
#  5.553412437438965,
#  5.531391143798828,
#  5.509613037109375,
#  5.396090507507324,
#  4.63945198059082,
#  2.663668632507324]

# %%
# Each column's missing value counts

chunk_iter = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1', chunksize=5000)
missing = []
for chunk in chunk_iter:
    # floats = chunk.select_dtypes(include=['float'])
    missing.append(chunk.apply(pd.isnull).sum())
    
combined_missing = pd.concat(missing)
combined_missing.groupby(combined_missing.index).sum().sort_values()
# Out:
# company_country_code          1
# company_name                  1
# company_permalink             1
# company_region                1
# investor_region               2
# investor_permalink            2
# investor_name                 2
# funded_quarter                3
# funded_at                     3
# funded_month                  3
# funded_year                   3
# funding_round_type            3
# company_state_code          492
# company_city                533
# company_category_code       643
# raised_amount_usd          3599
# investor_country_code     12001
# investor_city             12480
# investor_state_code       16809
# investor_category_code    50427
# dtype: int64

# %%
# Total chunk footprint and each column's memory footprint
chunk_iter = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1', chunksize=5000)
chunk_mem = []
for chunk in chunk_iter:
    chunk_mem.append(chunk.memory_usage(deep=True) / 2**20)

combined_mem = pd.concat(chunk_mem)
print("Total memory footprints: {}".format(combined_mem.sum()))
combined_mem.groupby(combined_mem.index).sum().sort_values()
# Out:
# Total memory footprints: 56.988484382629395
# Index                     0.000877
# funded_year               0.403366
# raised_amount_usd         0.403366
# investor_category_code    0.593590
# investor_state_code       2.361876
# investor_country_code     2.524654
# investor_city             2.751430
# company_state_code        2.962161
# company_country_code      3.025223
# funded_quarter            3.226837
# funded_month              3.226837
# investor_region           3.238946
# funding_round_type        3.252704
# company_region            3.253541
# company_category_code     3.262619
# company_city              3.343512
# funded_at                 3.378091
# company_name              3.424955
# investor_name             3.734270
# company_permalink         3.869808
# investor_permalink        4.749821
# dtype: float64

# %% [markdown]
# From observation, columns which we can drop because of lack of usefulness for analysis are: company_permalink, investor_permalink, funded_month, funded_quarter, and funded_year.

# %%
# convert to category
convert_col_dtypes = {
    "company_category_code": "category", "investor_category_code": "category", 
    "company_country_code": "category", "investor_country_code": "category", "investor_state_code": "category",
    "company_state_code": "category", "company_city": "category", "investor_city": "category"
}

# useful columns
useful_col = ['company_name', 'company_category_code', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'investor_name', 'investor_category_code', 'investor_country_code', 'investor_state_code', 'investor_region', 'investor_city', 'funding_round_type', 'funded_at', 'raised_amount_usd']

# %%
chunk_iter = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1', chunksize=5000, dtype=convert_col_dtypes, parse_dates=["funded_at"])
mv_counts = {}
chunk_mem = []
for chunk in chunk_iter:
    chunk = chunk[useful_col]
    chunk = chunk.dropna(how='all')
    float_cols = chunk.select_dtypes(include=['float'])
    for col in float_cols.columns:
        missing_values = len(chunk) - chunk[col].count()
        if col in mv_counts:
            mv_counts[col] = mv_counts[col] + missing_values
        else:
            mv_counts[col] = missing_values
    chunk_mem.append(chunk.memory_usage(deep=True).sum() / 2**20)
    chunk['raised_amount_usd'] = pd.to_numeric(chunk['raised_amount_usd'], downcast='float')
    

print(chunk.dtypes)
print(sum(chunk_mem))
# Out:
# company_name                      object
# company_category_code           category
# company_country_code            category
# company_state_code              category
# company_region                    object
# company_city                    category
# investor_name                     object
# investor_category_code          category
# investor_country_code           category
# investor_state_code             category
# investor_region                   object
# investor_city                   category
# funding_round_type                object
# funded_at                 datetime64[ns]
# raised_amount_usd                float32
# dtype: object
# 19.48626708984375

# %% [markdown]
# The dtype of each column is already optimized. We can reduce the file to 19.49 MB. It is huge improvement for dataframe optimization, at around 66% optimization.
#
# Now, we need to expand the processing code to export each chunk to a new table in the new SQLite database.

# %%
import sqlite3
conn = sqlite3.connect('investments.db')

chunk_iter = pd.read_csv('crunchbase-investments.csv', encoding='Latin-1', chunksize=5000, dtype=convert_col_dtypes, parse_dates=["funded_at"])

chunk_mem = []
for chunk in chunk_iter:
    chunk = chunk[useful_col]
    chunk = chunk.dropna(how='all')
    chunk_mem.append(chunk.memory_usage(deep=True).sum() / 2**20)
    chunk['raised_amount_usd'] = pd.to_numeric(chunk['raised_amount_usd'], downcast='float')
    chunk.to_sql('investments', conn, if_exists='append', index=False)

# %%
# Now we can query the code

pd.read_sql('select * from investments', conn)
# Out:
#                           company_name company_category_code  \
# 0                             AdverCar           advertising
# 1                           LaunchGram                  news
# 2                                 uTaP             messaging
# 3                             ZoopShop              software
# 4                             eFuneral                   web
# 5                                Tackk                   web
# 6                             Acclaimd             analytics
# 7                             Acclaimd             analytics
# 8                             ToVieFor             ecommerce
# 9                             OHK Labs                sports
# 10                              Lovely           real_estate
# 11                        peerTransfer               finance
# 12                            spotdock                   web
# 13                   Fisker Automotive            automotive
# 14                   Fisker Automotive            automotive
# 15                      MetroFlats.com                travel
# 16                            MesoCoat              nanotech
# 17                           Trilliant              hardware
# 18                        Power Assure       network_hosting
# 19                           Trilliant              hardware
# 20                           ECOtality             cleantech
# 21                              Evalve               biotech
# 22                              Ovalis               biotech
# 23              Alvine Pharmaceuticals               biotech
# 24                    Avaxia Biologics               biotech
# 25              AuraSense Therapeutics               biotech
# 26                        LibraryThing                   web
# 27                           HelioVolt             cleantech
# 28     Airband Communications Holdings                mobile
# 29                                Xand              software
# ...                                ...                   ...
# 52839                           Meddik                health
# 52840                       Blue Apron           hospitality
# 52841                           ChatID                mobile
# 52842          Breakthrough Behavioral                health
# 52843                            Plaid              software
# 52844                         PokitDok                mobile
# 52845                        Fitocracy                   web
# 52846                           Square                mobile
# 52847                          MixRank           advertising
# 52848                        Socialcam                mobile
# 52849                           Nuzzel                  news
# 52850                        ThirdLove             ecommerce
# 52851                            MXD3D                   web
# 52852                            MXD3D                   web
# 52853                          Verious                mobile
# 52854                       Identified             analytics
# 52855                      HaulerDeals               fashion
# 52856                    When You Wish             nonprofit
# 52857                         Farmeron             analytics
# 52858              Theraclone Sciences               biotech
# 52859                        SimpleGeo           advertising
# 52860                          Open Me             ecommerce
# 52861               Comprehend Systems            enterprise
# 52862                         Payoneer                 other
# 52863                         Outbrain                   web
# 52864                    Garantia Data            enterprise
# 52865                       DudaMobile                mobile
# 52866                       SiteBrains              software
# 52867               Comprehend Systems            enterprise
# 52868                      SmartThings                mobile
#
#       company_country_code company_state_code         company_region  \
# 0                      USA                 CA                 SF Bay
# 1                      USA                 CA                 SF Bay
# 2                      USA               None  United States - Other
# 3                      USA                 OH               Columbus
# 4                      USA                 OH              Cleveland
# 5                      USA                 OH              Cleveland
# 6                      USA                 OH               Columbus
# 7                      USA                 OH               Columbus
# 8                      USA                 NY               New York
# 9                      USA                 FL             Palm Beach
# 10                     USA                 CA                 SF Bay
# 11                     USA                 MA                 Boston
# 12                     USA                 NY               New York
# 13                     USA                 CA            Los Angeles
# 14                     USA                 CA            Los Angeles
# 15                     USA                 NJ            Cedar Grove
# 16                     USA                 OH              Cleveland
# 17                     USA                 CA                 SF Bay
# 18                     USA                 CA                 SF Bay
# 19                     USA                 CA                 SF Bay
# 20                     USA                 CA                 SF Bay
# 21                     USA                 CA                 SF Bay
# 22                     USA                 CA                 SF Bay
# 23                     USA                 CA                 SF Bay
# 24                     USA                 MA                 Boston
# 25                     USA                 IL                Chicago
# 26                     USA                 ME               Portland
# 27                     USA                 TX                 Austin
# 28                     USA                 TX                 Dallas
# 29                     USA                 NY               New York
# ...                    ...                ...                    ...
# 52839                  USA                 NY               New York
# 52840                  USA                 NY               New York
# 52841                  USA                 NY               New York
# 52842                  USA                 CA                 SF Bay
# 52843                  USA                 CA                 SF Bay
# 52844                  USA                 CA                 SF Bay
# 52845                  USA                 NY               New York
# 52846                  USA                 CA                 SF Bay
# 52847                  USA                 CA                 SF Bay
# 52848                  USA                 CA     Santa Clara County
# 52849                  USA                 CA                 SF Bay
# 52850                  USA                 CA                 SF Bay
# 52851                  USA                 CA                 SF Bay
# 52852                  USA                 CA                 SF Bay
# 52853                  USA                 CA                 SF Bay
# 52854                  USA                 CA                 SF Bay
# 52855                  USA                 CA            Los Angeles
# 52856                  USA                 CA            Los Angeles
# 52857                  USA                 CA                 SF Bay
# 52858                  USA                 WA                Seattle
# 52859                  USA                 CA                 SF Bay
# 52860                  USA                 CA            Los Angeles
# 52861                  USA                 CA                 SF Bay
# 52862                  USA                 NY               New York
# 52863                  USA                 NY               New York
# 52864                  USA                 CA                 SF Bay
# 52865                  USA                 CA                 SF Bay
# 52866                  USA                 CA                 SF Bay
# 52867                  USA                 CA                 SF Bay
# 52868                  USA                 DC                unknown
#
#              company_city                             investor_name  \
# 0           San Francisco                         1-800-FLOWERS.COM
# 1           Mountain View                               10Xelerator
# 2                    None                               10Xelerator
# 3                columbus                               10Xelerator
# 4               Cleveland                               10Xelerator
# 5               Cleveland                               10Xelerator
# 6                Columbus                               10Xelerator
# 7                Columbus                               10Xelerator
# 8                New York  2010 NYU Stern Business Plan Competition
# 9              Boca Raton                           22Hundred Group
# 10          San Francisco                                     3taps
# 11                 Boston                                  500 Hats
# 12                    NYC                              9mmedia, LLC
# 13                 Irvine                              A123 Systems
# 14                 Irvine                              A123 Systems
# 15            Cedar Grove                            AA Investments
# 16                 Euclid                                    Abakan
# 17           Redwood City                                       ABB
# 18            Santa Clara                                       ABB
# 19           Redwood City                                       ABB
# 20          San Francisco                                       ABB
# 21             Menlo Park                               Abbott Labs
# 22          Mountain View                               Abbott Labs
# 23             San Carlos                                    AbbVie
# 24              Lexington                                    AbbVie
# 25               Evanston                                    AbbVie
# 26               Portland                                  AbeBooks
# 27                 Austin                             Abengoa Solar
# 28                 Dallas                             ABRY Partners
# 29              Hawthorne                             ABRY Partners
# ...                   ...                                       ...
# 52839            New York                             Zach Weinberg
# 52840            Brooklyn                             Zach Weinberg
# 52841            New York                             Zach Weinberg
# 52842        Redwood City                             Zach Weinberg
# 52843       San Francisco                             Zach Weinberg
# 52844          Menlo Park                              Zach Zeitlin
# 52845            New York                            Zachary Aarons
# 52846       San Francisco                             Zachary Bogue
# 52847       San Francisco                             Zachary Bogue
# 52848  Santa Clara County                             Zachary Bogue
# 52849       San Francisco                             Zachary Bogue
# 52850       San Francisco                             Zachary Bogue
# 52851       San Francisco                                Zaid Ayoub
# 52852       San Francisco                                Zaid Ayoub
# 52853          San Carlos                                 Zain Khan
# 52854       San Francisco                                  Zao Yang
# 52855         Los Angeles                                  Zaw Thet
# 52856      Marina Del Rey                              Zelda Marzec
# 52857       Mountain View                            Zeljko Mataija
# 52858             Seattle                             Zenyaku Kogyo
# 52859       San Francisco                                Ziv Navoth
# 52860         Los Angeles                                Ziver Birg
# 52861           Palo Alto                                 Zod Nazem
# 52862            New York                               Zohar Gilon
# 52863       New York City                               Zohar Gilon
# 52864         Santa Clara                               Zohar Gilon
# 52865           Palo Alto                               Zohar Gilon
# 52866       San Francisco                              zohar israel
# 52867           Palo Alto                           Zorba Lieberman
# 52868         Minneapolis                              Zorik Gordon
#
#       investor_category_code investor_country_code investor_state_code  \
# 0                       None                   USA                  NY
# 1                    finance                   USA                  OH
# 2                    finance                   USA                  OH
# 3                    finance                   USA                  OH
# 4                    finance                   USA                  OH
# 5                    finance                   USA                  OH
# 6                    finance                   USA                  OH
# 7                    finance                   USA                  OH
# 8                       None                  None                None
# 9                       None                  None                None
# 10                       web                   USA                  CA
# 11                      None                   USA                  CA
# 12                      None                  None                None
# 13                  nanotech                   USA                  MA
# 14                  nanotech                   USA                  MA
# 15                      None                   BMU                None
# 16                 cleantech                   USA                  FL
# 17                 cleantech                   CHE                None
# 18                 cleantech                   CHE                None
# 19                 cleantech                   CHE                None
# 20                 cleantech                   CHE                None
# 21                   biotech                   USA                  IL
# 22                   biotech                   USA                  IL
# 23                   biotech                   USA                  IL
# 24                   biotech                   USA                  IL
# 25                   biotech                   USA                  IL
# 26                       web                   CAN                None
# 27                 cleantech                   ESP                None
# 28                     other                   USA                  MA
# 29                     other                   USA                  MA
# ...                      ...                   ...                 ...
# 52839                   None                  None                None
# 52840                   None                  None                None
# 52841                   None                  None                None
# 52842                   None                  None                None
# 52843                   None                  None                None
# 52844                   None                  None                None
# 52845                   None                  None                None
# 52846                   None                  None                None
# 52847                   None                  None                None
# 52848                   None                  None                None
# 52849                   None                  None                None
# 52850                   None                  None                None
# 52851                   None                  None                None
# 52852                   None                  None                None
# 52853                   None                  None                None
# 52854                   None                  None                None
# 52855                   None                  None                None
# 52856                   None                  None                None
# 52857                   None                  None                None
# 52858                   None                  None                None
# 52859                   None                  None                None
# 52860                   None                  None                None
# 52861                   None                  None                None
# 52862                   None                  None                None
# 52863                   None                  None                None
# 52864                   None                  None                None
# 52865                   None                  None                None
# 52866                   None                  None                None
# 52867                   None                  None                None
# 52868                   None                  None                None
#
#        investor_region  investor_city funding_round_type            funded_at  \
# 0             New York       New York           series-a  2012-10-30 00:00:00
# 1             Columbus       Columbus              other  2012-01-23 00:00:00
# 2             Columbus       Columbus              other  2012-01-01 00:00:00
# 3             Columbus       Columbus              angel  2012-02-15 00:00:00
# 4             Columbus       Columbus              other  2011-09-08 00:00:00
# 5             Columbus       Columbus              other  2012-02-01 00:00:00
# 6             Columbus       Columbus              angel  2012-06-01 00:00:00
# 7             Columbus       Columbus              angel  2012-08-07 00:00:00
# 8              unknown           None              angel  2010-04-01 00:00:00
# 9              unknown           None              angel  2011-09-01 00:00:00
# 10              SF Bay  San Francisco           series-a  2012-10-01 00:00:00
# 11              SF Bay      Palo Alto              angel  2010-10-28 00:00:00
# 12             unknown           None              angel  2012-01-10 00:00:00
# 13              Boston      Watertown           series-a  2010-05-01 00:00:00
# 14              Boston      Watertown            venture  2011-02-22 00:00:00
# 15     Bermuda - Other           None              angel  2010-08-18 00:00:00
# 16               Miami          Miami            venture  2009-12-14 00:00:00
# 17              Zurich         Zurich           series-b  2010-07-15 00:00:00
# 18              Zurich         Zurich            venture  2010-09-20 00:00:00
# 19              Zurich         Zurich            venture  2010-12-21 00:00:00
# 20              Zurich         Zurich            venture  2011-01-09 00:00:00
# 21             Chicago    Des Plaines          series-c+  2007-11-27 00:00:00
# 22             Chicago    Des Plaines           series-b  2007-01-30 00:00:00
# 23             Chicago        Chicago     private-equity  2013-05-14 00:00:00
# 24             Chicago        Chicago           series-b  2013-06-07 00:00:00
# 25             Chicago        Chicago           series-b  2013-07-31 00:00:00
# 26            Victoria       Victoria           series-a  2006-05-16 00:00:00
# 27             Sevilla        Sevilla           series-b  2007-10-23 00:00:00
# 28              Boston         Boston            venture  2011-08-11 00:00:00
# 29              Boston         Boston              other  2013-09-12 00:00:00
# ...                ...            ...                ...                  ...
# 52839          unknown           None              angel  2012-05-24 00:00:00
# 52840          unknown           None           series-a  2013-02-19 00:00:00
# 52841          unknown           None              angel  2012-01-01 00:00:00
# 52842          unknown           None              angel  2012-08-13 00:00:00
# 52843          unknown           None           series-a  2013-09-19 00:00:00
# 52844          unknown           None              angel  2012-07-12 00:00:00
# 52845          unknown           None              angel  2011-09-01 00:00:00
# 52846          unknown           None           series-a  2009-11-01 00:00:00
# 52847          unknown           None           series-a  2011-11-18 00:00:00
# 52848          unknown           None              angel  2012-04-30 00:00:00
# 52849          unknown           None            venture  2012-11-15 00:00:00
# 52850          unknown           None           series-a  2012-12-01 00:00:00
# 52851          unknown           None              angel  2012-01-01 00:00:00
# 52852          unknown           None              angel  2011-01-01 00:00:00
# 52853          unknown           None              angel  2011-05-30 00:00:00
# 52854          unknown           None           series-b  2012-06-05 00:00:00
# 52855          unknown           None              angel  2012-10-31 00:00:00
# 52856          unknown           None           series-a  2011-02-01 00:00:00
# 52857          unknown           None              angel  2010-10-01 00:00:00
# 52858          unknown           None           series-b  2013-03-25 00:00:00
# 52859          unknown           None              other  2009-11-10 00:00:00
# 52860          unknown           None              angel  2013-08-01 00:00:00
# 52861          unknown           None           series-a  2013-07-11 00:00:00
# 52862          unknown           None           series-a  2005-01-01 00:00:00
# 52863          unknown           None           series-b  2009-02-11 00:00:00
# 52864          unknown           None           series-a  2012-08-08 00:00:00
# 52865          unknown           None          series-c+  2013-04-08 00:00:00
# 52866          unknown           None              angel  2010-08-01 00:00:00
# 52867          unknown           None           series-a  2013-07-11 00:00:00
# 52868          unknown           None           series-a  2012-12-04 00:00:00
#
#        raised_amount_usd
# 0              2000000.0
# 1                20000.0
# 2                20000.0
# 3                20000.0
# 4                20000.0
# 5                20000.0
# 6                20000.0
# 7                70000.0
# 8                75000.0
# 9               100000.0
# 10             2000000.0
# 11             1100000.0
# 12              600000.0
# 13           189000000.0
# 14           150000000.0
# 15                   NaN
# 16                   NaN
# 17           106000000.0
# 18             1500000.0
# 19                   NaN
# 20            10000000.0
# 21            60000000.0
# 22             6600000.0
# 23            70000000.0
# 24            11500000.0
# 25                   NaN
# 26                   NaN
# 27           101000000.0
# 28            20000000.0
# 29           200000000.0
# ...                  ...
# 52839           750000.0
# 52840          3000000.0
# 52841                NaN
# 52842           900000.0
# 52843          2800000.0
# 52844          1300000.0
# 52845           250000.0
# 52846         10000000.0
# 52847          1500000.0
# 52848                NaN
# 52849          1700000.0
# 52850          5600000.0
# 52851           300000.0
# 52852           300000.0
# 52853           800000.0
# 52854         21000000.0
# 52855          1250000.0
# 52856          1500000.0
# 52857            15000.0
# 52858          8000000.0
# 52859           195000.0
# 52860                NaN
# 52861          8400000.0
# 52862          2000000.0
# 52863         12000000.0
# 52864          3800000.0
# 52865         10300000.0
# 52866           350000.0
# 52867          8400000.0
# 52868          3000000.0
#
# [52869 rows x 15 columns]

# %%
pd.read_sql('PRAGMA table_info(investments)', conn)
# Out:
#     cid                    name       type  notnull dflt_value  pk
# 0     0            company_name       TEXT        0       None   0
# 1     1   company_category_code       TEXT        0       None   0
# 2     2    company_country_code       TEXT        0       None   0
# 3     3      company_state_code       TEXT        0       None   0
# 4     4          company_region       TEXT        0       None   0
# 5     5            company_city       TEXT        0       None   0
# 6     6           investor_name       TEXT        0       None   0
# 7     7  investor_category_code       TEXT        0       None   0
# 8     8   investor_country_code       TEXT        0       None   0
# 9     9     investor_state_code       TEXT        0       None   0
# 10   10         investor_region       TEXT        0       None   0
# 11   11           investor_city       TEXT        0       None   0
# 12   12      funding_round_type       TEXT        0       None   0
# 13   13               funded_at  TIMESTAMP        0       None   0
# 14   14       raised_amount_usd       REAL        0       None   0

# %%
# !wc
