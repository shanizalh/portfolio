# %% [markdown]
# # Analyzing Stock Prices
# Skills: Stacks/queues, Arrays and lists algorithm, hash tables
#
# In this project, we'll work with stock market data that was downloaded from Yahoo Finance using the yahoo_finance Python package. This data consists of the daily stock prices from 2007-1-1 to 2017-04-17 for several hundred stock symbols traded on the NASDAQ stock exchange, stored in the prices folder. The download_data.py script in the same folder as the Jupyter notebook was used to download all of the stock price data. Each file in the prices folder is named for a specific stock symbol.
#
# To read in and store all of the data, we'll need several layers of indices:
#
# Layer 1 -- the stock symbol, or an numeric index representing the stock symbol.
# Layer 2 -- the rows in a stock symbol csv file.
# Layer 3 -- The column names in a stock symbol csv file

# %% [markdown]
# My choice for appropriate data structure for layer 1, 2, and 3 is:
# Hash table, list, list.
#
# I chose this data structure because, for layer 1, there is fix and limited amount of different variable (stock symbol). So we can easily hash the symbols provided.

# %% [markdown]
# First, we must use multiple processes to read the data into the data structure we chose. But before that, we should see what is inside our directory, how many files, and what is inside of the file.

# %%
# First, we see what kind of files inside our directory
import os
files = os.listdir('prices')
files
# Out:
# ['aal.csv',
#  'aame.csv',
#  'aaon.csv',
#  'aapl.csv',
#  'aaww.csv',
#  'aaxn.csv',
#  'abax.csv',
#  'abcb.csv',
#  'abco.csv',
#  'abeo.csv',
#  'abio.csv',
#  'abmd.csv',
#  'abtl.csv',
#  'acad.csv',
#  'acet.csv',
#  'acfc.csv',
#  'acgl.csv',
#  'achc.csv',
#  'achn.csv',
#  'aciw.csv',
#  'acls.csv',
#  'acnb.csv',
#  'acor.csv',
#  'acta.csv',
#  'actg.csv',
#  'acxm.csv',
#  'adbe.csv',
#  'adi.csv',
#  'admp.csv',
#  'adp.csv',
#  'adra.csv',
#  'adrd.csv',
#  'adre.csv',
#  'adru.csv',
#  'adsk.csv',
#  'adtn.csv',
#  'adxs.csv',
#  'aegn.csv',
#  'aehr.csv',
#  'aeis.csv',
#  'aemd.csv',
#  'aey.csv',
#  'aezs.csv',
#  'afam.csv',
#  'afsi.csv',
#  'agen.csv',
#  'agii.csv',
#  'agys.csv',
#  'ahgp.csv',
#  'ahpi.csv',
#  'aimc.csv',
#  'ainv.csv',
#  'aiq.csv',
#  'airm.csv',
#  'airt.csv',
#  'akam.csv',
#  'akrx.csv',
#  'alco.csv',
#  'algn.csv',
#  'algt.csv',
#  'alks.csv',
#  'allt.csv',
#  'alny.csv',
#  'alog.csv',
#  'alot.csv',
#  'alqa.csv',
#  'alsk.csv',
#  'alxn.csv',
#  'amag.csv',
#  'amat.csv',
#  'amd.csv',
#  'amed.csv',
#  'amgn.csv',
#  'amkr.csv',
#  'amnb.csv',
#  'amot.csv',
#  'amrb.csv',
#  'amri.csv',
#  'amrn.csv',
#  'amsc.csv',
#  'amsf.csv',
#  'amswa.csv',
#  'amtd.csv',
#  'amwd.csv',
#  'amzn.csv',
#  'anat.csv',
#  'ancx.csv',
#  'ande.csv',
#  'ango.csv',
#  'anik.csv',
#  'anip.csv',
#  'anss.csv',
#  'aobc.csv',
#  'apdn.csv',
#  'aplp.csv',
#  'apog.csv',
#  'apps.csv',
#  'apri.csv',
#  'apwc.csv',
#  'aray.csv',
#  'arcb.csv',
#  'arcc.csv',
#  'arci.csv',
#  'arcw.csv',
#  'ardm.csv',
#  'arii.csv',
#  'aris.csv',
#  'arkr.csv',
#  'arlp.csv',
#  'arlz.csv',
#  'arna.csv',
#  'arow.csv',
#  'arql.csv',
#  'arrs.csv',
#  'arry.csv',
#  'artna.csv',
#  'artw.csv',
#  'artx.csv',
#  'arwr.csv',
#  'asfi.csv',
#  'asml.csv',
#  'asna.csv',
#  'asrv.csv',
#  'asrvp.csv',
#  'astc.csv',
#  'aste.csv',
#  'asur.csv',
#  'asys.csv',
#  'atax.csv',
#  'atec.csv',
#  'atlc.csv',
#  'atlo.csv',
#  'atni.csv',
#  'atrc.csv',
#  'atri.csv',
#  'atro.csv',
#  'atrs.csv',
#  'atsg.csv',
#  'attu.csv',
#  'atvi.csv',
#  'aubn.csv',
#  'audc.csv',
#  'avav.csv',
#  'avdl.csv',
#  'avhi.csv',
#  'avir.csv',
#  'avnw.csv',
#  'awre.csv',
#  'axas.csv',
#  'axdx.csv',
#  'axgn.csv',
#  'axti.csv',
#  'azpn.csv',
#  'baby.csv',
#  'banf.csv',
#  'banfp.csv',
#  'banr.csv',
#  'basi.csv',
#  'bbby.csv',
#  'bbgi.csv',
#  'bbh.csv',
#  'bbox.csv',
#  'bbry.csv',
#  'bbsi.csv',
#  'bcbp.csv',
#  'bcli.csv',
#  'bcor.csv',
#  'bcpc.csv',
#  'bcrx.csv',
#  'bde.csv',
#  'bdge.csv',
#  'bdsi.csv',
#  'bebe.csv',
#  'becn.csv',
#  'belfa.csv',
#  'belfb.csv',
#  'bfin.csv',
#  'bgcp.csv',
#  'bgfv.csv',
#  'bidu.csv',
#  'biib.csv',
#  'biol.csv',
#  'bios.csv',
#  'bjri.csv',
#  'bkmu.csv',
#  'bksc.csv',
#  'bldp.csv',
#  'bldr.csv',
#  'blfs.csv',
#  'blkb.csv',
#  'bmra.csv',
#  'bmrc.csv',
#  'bmrn.csv',
#  'bmtc.csv',
#  'bncn.csv',
#  'bnso.csv',
#  'bobe.csv',
#  'boch.csv',
#  'bofi.csv',
#  'bokf.csv',
#  'bont.csv',
#  'boom.csv',
#  'bosc.csv',
#  'botj.csv',
#  'bpop.csv',
#  'bpopn.csv',
#  'brcd.csv',
#  'brew.csv',
#  'brid.csv',
#  'brkl.csv',
#  'brkr.csv',
#  'brks.csv',
#  'bset.csv',
#  'bsf.csv',
#  'bsqr.csv',
#  'bsrr.csv',
#  'bstc.csv',
#  'buse.csv',
#  'bvsn.csv',
#  'bwen.csv',
#  'bwina.csv',
#  'bwinb.csv',
#  'bwld.csv',
#  'bybk.csv',
#  'byfc.csv',
#  'ca.csv',
#  'caas.csv',
#  'cac.csv',
#  'cacb.csv',
#  'cacc.csv',
#  'cake.csv',
#  'cald.csv',
#  'call.csv',
#  'calm.csv',
#  'camp.csv',
#  'camt.csv',
#  'capr.csv',
#  'car.csv',
#  'cart.csv',
#  'carv.csv',
#  'casc.csv',
#  'cash.csv',
#  'casi.csv',
#  'casm.csv',
#  'cass.csv',
#  'casy.csv',
#  'caty.csv',
#  'cbak.csv',
#  'cban.csv',
#  'cbfv.csv',
#  'cbio.csv',
#  'cbli.csv',
#  'cbmx.csv',
#  'cbrl.csv',
#  'cbsh.csv',
#  'ccbg.csv',
#  'ccmp.csv',
#  'ccne.csv',
#  'ccoi.csv',
#  'ccrn.csv',
#  'ccur.csv',
#  'cdns.csv',
#  'cdor.csv',
#  'cdti.csv',
#  'cdzi.csv',
#  'cece.csv',
#  'ceco.csv',
#  'celg.csv',
#  'cemi.csv',
#  'cent.csv',
#  'centa.csv',
#  'cenx.csv',
#  'cern.csv',
#  'cers.csv',
#  'cetv.csv',
#  'ceva.csv',
#  'cfbk.csv',
#  'cfcb.csv',
#  'cffi.csv',
#  'cffn.csv',
#  'cfnb.csv',
#  'cfnl.csv',
#  'cgen.csv',
#  'cgnt.csv',
#  'cgnx.csv',
#  'cgo.csv',
#  'chci.csv',
#  'chco.csv',
#  'chdn.csv',
#  'chfc.csv',
#  'chfn.csv',
#  'chi.csv',
#  'chke.csv',
#  'chkp.csv',
#  'chmg.csv',
#  'chnr.csv',
#  'chrw.csv',
#  'chscp.csv',
#  'chy.csv',
#  'cidm.csv',
#  'cigi.csv',
#  'cinf.csv',
#  'civb.csv',
#  'cizn.csv',
#  'clbs.csv',
#  'clct.csv',
#  'cldx.csv',
#  'clfd.csv',
#  'clmt.csv',
#  'clrb.csv',
#  'clro.csv',
#  'clsn.csv',
#  'club.csv',
#  'clwt.csv',
#  'cmco.csv',
#  'cmcsa.csv',
#  'cmct.csv',
#  'cme.csv',
#  'cmls.csv',
#  'cmpr.csv',
#  'cmtl.csv',
#  'cnbka.csv',
#  'cnit.csv',
#  'cnmd.csv',
#  'cnob.csv',
#  'cnsl.csv',
#  'cntf.csv',
#  'cnty.csv',
#  'cnxn.csv',
#  'cobz.csv',
#  'cohr.csv',
#  'cohu.csv',
#  'coke.csv',
#  'colb.csv',
#  'colm.csv',
#  'conn.csv',
#  'cool.csv',
#  'core.csv',
#  'cort.csv',
#  'cost.csv',
#  'cown.csv',
#  'cpah.csv',
#  'cpla.csv',
#  'cplp.csv',
#  'cprt.csv',
#  'cprx.csv',
#  'cpsh.csv',
#  'cpsi.csv',
#  'cpss.csv',
#  'cpst.csv',
#  'crai.csv',
#  'cray.csv',
#  'crds.csv',
#  'cree.csv',
#  'creg.csv',
#  'cresy.csv',
#  'cris.csv',
#  'crme.csv',
#  'crmt.csv',
#  'crnt.csv',
#  'crox.csv',
#  'crtn.csv',
#  'crus.csv',
#  'crvl.csv',
#  'crws.csv',
#  'crzo.csv',
#  'csbk.csv',
#  'csbr.csv',
#  'csco.csv',
#  'csfl.csv',
#  'csgp.csv',
#  'csgs.csv',
#  'csii.csv',
#  'csiq.csv',
#  'cspi.csv',
#  'csq.csv',
#  'cswc.csv',
#  'csx.csv',
#  'ctas.csv',
#  'ctbi.csv',
#  'ctg.csv',
#  'cthr.csv',
#  'ctib.csv',
#  'ctic.csv',
#  'ctrn.csv',
#  'ctrp.csv',
#  'ctsh.csv',
#  'ctws.csv',
#  'ctxs.csv',
#  'cuba.csv',
#  'cui.csv',
#  'cunb.csv',
#  'cur.csv',
#  'cutr.csv',
#  'cvbf.csv',
#  'cvco.csv',
#  'cvcy.csv',
#  'cvgi.csv',
#  'cvgw.csv',
#  'cvlt.csv',
#  'cvly.csv',
#  'cvti.csv',
#  'cvv.csv',
#  'cwbc.csv',
#  'cwco.csv',
#  'cwst.csv',
#  'cy.csv',
#  'cyan.csv',
#  'cybe.csv',
#  'cycc.csv',
#  'cyccp.csv',
#  'cyrn.csv',
#  'cyrx.csv',
#  'cytk.csv',
#  'cytr.csv',
#  'cytx.csv',
#  'czfc.csv',
#  'cznc.csv',
#  'czwi.csv',
#  'daio.csv',
#  'dakt.csv',
#  'dave.csv',
#  'dcom.csv',
#  'dcth.csv',
#  'denn.csv',
#  'depo.csv',
#  'dest.csv',
#  'dfbg.csv',
#  'dgas.csv',
#  'dgica.csv',
#  'dgicb.csv',
#  'dgii.csv',
#  'dhil.csv',
#  'diod.csv',
#  'disca.csv',
#  'discb.csv',
#  'dish.csv',
#  'djco.csv',
#  'dlhc.csv',
#  'dltr.csv',
#  'dmlp.csv',
#  'dmrc.csv',
#  'dnbf.csv',
#  'dorm.csv',
#  'dox.csv',
#  'drad.csv',
#  'dram.csv',
#  'drrx.csv',
#  'drys.csv',
#  'dsgx.csv',
#  'dspg.csv',
#  'dswl.csv',
#  'dtrm.csv',
#  'dvax.csv',
#  'dvcr.csv',
#  'dwaq.csv',
#  'dwch.csv',
#  'dwsn.csv',
#  'dxcm.csv',
#  'dxpe.csv',
#  'dxtr.csv',
#  'dxyn.csv',
#  'dynt.csv',
#  'dysl.csv',
#  'dzsi.csv',
#  'ea.csv',
#  'ebay.csv',
#  'ebix.csv',
#  'ebtc.csv',
#  'ecol.csv',
#  'ecpg.csv',
#  'edap.csv',
#  'edgw.csv',
#  'educ.csv',
#  'eeft.csv',
#  'eei.csv',
#  'efii.csv',
#  'efsc.csv',
#  'egan.csv',
#  'egbn.csv',
#  'eght.csv',
#  'egle.csv',
#  'egt.csv',
#  'ehth.csv',
#  'elgx.csv',
#  'elon.csv',
#  'elos.csv',
#  'else.csv',
#  'eltk.csv',
#  'emcf.csv',
#  'emci.csv',
#  'emitf.csv',
#  'emkr.csv',
#  'eml.csv',
#  'emms.csv',
#  'endp.csv',
#  'eng.csv',
#  'entg.csv',
#  'epay.csv',
#  'eqfn.csv',
#  'eqix.csv',
#  'eric.csv',
#  'esbk.csv',
#  'esca.csv',
#  'esgr.csv',
#  'esio.csv',
#  'eslt.csv',
#  'esnd.csv',
#  'esrx.csv',
#  'essa.csv',
#  'esxb.csv',
#  'etfc.csv',
#  'evbs.csv',
#  'evep.csv',
#  'evlv.csv',
#  'evol.csv',
#  'ewbc.csv',
#  'exac.csv',
#  'exas.csv',
#  'exel.csv',
#  'exfo.csv',
#  'exls.csv',
#  'expd.csv',
#  'expe.csv',
#  'expo.csv',
#  'extr.csv',
#  'ezpw.csv',
#  'falc.csv',
#  'farm.csv',
#  'faro.csv',
#  'fast.csv',
#  'fbiz.csv',
#  'fbms.csv',
#  'fbnc.csv',
#  'fbss.csv',
#  'fcap.csv',
#  'fcco.csv',
#  'fccy.csv',
#  'fcnca.csv',
#  'fdef.csv',
#  'feim.csv',
#  'fele.csv',
#  'ffbc.csv',
#  'ffhl.csv',
#  'ffic.csv',
#  'ffin.csv',
#  'ffiv.csv',
#  'ffkt.csv',
#  'fhco.csv',
#  'finl.csv',
#  'fisi.csv',
#  'fisv.csv',
#  'fizz.csv',
#  'flex.csv',
#  'flic.csv',
#  'flir.csv',
#  'fll.csv',
#  'flws.csv',
#  'flxs.csv',
#  'fmbi.csv']

# %%
# How many files in direcory
len(files)
# Out:
# 560

# %%
# Sampling one file to see what is inside

with open('prices/{}'.format(files[280])) as file:
        data = file.read().strip()
        key = files[280].replace(".csv","")
        value = data.split("\n")
        value = [v.split(",") for v in value]
        print(value)
# Out:
# [['date', 'close', 'open', 'high', 'low', 'volume'], ['2007-01-03', '13.70', '13.10', '14.00', '13.10', '6900'], ['2007-01-04', '13.61', '13.61', '13.61', '13.61', '100'], ['2007-01-05', '13.65', '13.65', '13.65', '13.65', '100'], ['2007-01-08', '13.60', '13.60', '13.60', '13.60', '100'], ['2007-01-09', '13.60', '13.60', '13.60', '13.60', '000'], ['2007-01-10', '13.60', '13.60', '13.60', '13.60', '000'], ['2007-01-11', '13.65', '13.56', '13.65', '13.56', '2200'], ['2007-01-12', '13.79', '13.65', '13.79', '13.51', '2800'], ['2007-01-16', '13.79', '13.79', '13.79', '13.79', '000'], ['2007-01-17', '13.51', '13.51', '13.51', '13.51', '2400'], ['2007-01-18', '13.51', '13.51', '13.51', '13.51', '000'], ['2007-01-19', '13.51', '13.51', '13.51', '13.51', '000'], ['2007-01-22', '13.80', '13.80', '14.00', '13.74', '700'], ['2007-01-23', '13.80', '13.80', '13.80', '13.80', '000'], ['2007-01-24', '14.06', '14.00', '14.06', '14.00', '2000'], ['2007-01-25', '14.06', '14.06', '14.06', '14.06', '000'], ['2007-01-26', '13.93', '13.71', '13.93', '13.36', '4100'], ['2007-01-29', '13.93', '13.93', '13.93', '13.93', '000'], ['2007-01-30', '13.93', '13.93', '13.93', '13.93', '000'], ['2007-01-31', '14.00', '14.00', '14.00', '14.00', '2000'], ['2007-02-01', '14.00', '14.00', '14.00', '14.00', '700'], ['2007-02-02', '14.02', '14.00', '14.06', '13.61', '6000'], ['2007-02-05', '14.02', '14.02', '14.02', '14.02', '000'], ['2007-02-06', '14.02', '14.02', '14.02', '14.02', '000'], ['2007-02-07', '14.10', '13.75', '14.10', '13.69', '3800'], ['2007-02-08', '13.99', '13.66', '13.99', '13.66', '1700'], ['2007-02-09', '13.99', '13.99', '13.99', '13.99', '000'], ['2007-02-12', '13.99', '13.99', '13.99', '13.99', '000'], ['2007-02-13', '13.99', '13.99', '13.99', '13.99', '000'], ['2007-02-14', '14.15', '14.39', '14.39', '14.15', '500'], ['2007-02-15', '13.76', '13.75', '13.85', '12.95', '6400'], ['2007-02-16', '13.66', '13.66', '13.66', '13.66', '300'], ['2007-02-20', '13.85', '13.73', '13.85', '13.73', '1200'], ['2007-02-21', '12.89', '13.71', '13.71', '12.89', '2100'], ['2007-02-22', '13.39', '13.25', '13.47', '13.25', '1000'], ['2007-02-23', '13.45', '13.45', '13.45', '13.45', '300'], ['2007-02-26', '13.45', '13.45', '13.45', '13.45', '000'], ['2007-02-27', '13.45', '13.45', '13.45', '13.45', '000'], ['2007-02-28', '13.52', '13.90', '13.90', '13.51', '900'], ['2007-03-01', '13.60', '13.57', '13.60', '13.55', '700'], ['2007-03-02', '13.87', '14.00', '14.00', '13.28', '31600'], ['2007-03-05', '13.31', '13.31', '13.31', '13.31', '1000'], ['2007-03-06', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-07', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-08', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-09', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-12', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-13', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-14', '13.90', '13.98', '14.00', '13.76', '3300'], ['2007-03-15', '13.83', '13.83', '13.83', '13.83', '100'], ['2007-03-16', '13.83', '13.83', '13.83', '13.83', '000'], ['2007-03-19', '13.83', '13.83', '13.83', '13.83', '000'], ['2007-03-20', '13.31', '13.31', '13.31', '13.31', '1000'], ['2007-03-21', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-22', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-23', '13.31', '13.31', '13.31', '13.31', '000'], ['2007-03-26', '13.32', '13.60', '13.60', '13.18', '3100'], ['2007-03-27', '13.40', '13.40', '13.40', '13.39', '29800'], ['2007-03-28', '13.40', '13.40', '13.40', '13.40', '000'], ['2007-03-29', '13.39', '13.27', '13.39', '13.27', '1200'], ['2007-03-30', '13.15', '13.22', '13.39', '12.75', '24000'], ['2007-04-02', '12.85', '12.98', '13.31', '12.73', '6700'], ['2007-04-03', '12.96', '13.03', '13.31', '12.95', '2800'], ['2007-04-04', '12.88', '13.38', '13.38', '12.88', '600'], ['2007-04-05', '12.88', '12.88', '12.88', '12.88', '000'], ['2007-04-09', '13.09', '12.94', '13.22', '12.75', '2100'], ['2007-04-10', '12.78', ' ...

# %% [markdown]
# Now we have some idea what kind of content inside the file, now we'll process to read data using multithreading.

# %%
import concurrent.futures as cf

def read_data(files):
    with open('prices/{}'.format(files)) as file:
        data = file.read().strip()
        key = files.replace(".csv","")
        value = data.split("\n")
        value = [v.split(",") for v in value]
        return key, value

pool = cf.ThreadPoolExecutor(max_workers=4)
list_content = list(pool.map(read_data, files))
content = dict(list_content)

# %%
transformed = {}

for key1 in content.keys():
    transformed[key1] = {}
    counter = 0
    for key2 in content[key1][0]:
        transformed[key1][key2]  = [content[key1][i][counter] for i in range(1,len(content[key1]))]
        counter += 1

# %% [markdown]
# After the data is transformed, we can easily do some aggregation. For example, the average volume for each stock.

# %%
# Average volume each company
volume_avg = {}
for company in transformed.keys():
    volumes = [int(i) for i in transformed[company]['volume']]
    volume_avg[company] = sum(volumes)/len(volumes)
    
volume_avg
# Out:
# {'aal': 8469080.501930501,
#  'aame': 6318.918918918919,
#  'aaon': 211263.861003861,
#  'aapl': 130112422.35521236,
#  'aaww': 287414.78764478763,
#  'aaxn': 1259518.9961389962,
#  'abax': 194647.83783783784,
#  'abcb': 92016.02316602317,
#  'abco': 276554.0540540541,
#  'abeo': 142349.69111969112,
#  'abio': 25513.629343629345,
#  'abmd': 401411.9305019305,
#  'abtl': 70726.21621621621,
#  'acad': 1265892.5482625482,
#  'acet': 162641.66023166024,
#  'acfc': 11198.764478764479,
#  'acgl': 839836.833976834,
#  'achc': 297078.5714285714,
#  'achn': 1428632.1621621621,
#  'aciw': 803301.2355212355,
#  'acls': 208106.67953667953,
#  'acnb': 3627.4517374517372,
#  'acor': 603703.9768339768,
#  'acta': 169822.47104247104,
#  'actg': 417181.4285714286,
#  'acxm': 550136.6795366795,
#  'adbe': 5341678.532818533,
#  'adi': 3337189.034749035,
#  'admp': 67102.54826254827,
#  'adp': 2804884.092664093,
#  'adra': 10941.505791505791,
#  'adrd': 17613.320463320462,
#  'adre': 131657.83783783784,
#  'adru': 6654.980694980695,
#  'adsk': 3142473.7837837837,
#  'adtn': 869738.4555984556,
#  'adxs': 787985.9073359073,
#  'aegn': 290532.7027027027,
#  'aehr': 41511.08108108108,
#  'aeis': 438154.0540540541,
#  'aemd': 14546.100386100386,
#  'aey': 24661.04247104247,
#  'aezs': 98073.74517374518,
#  'afam': 110272.74131274132,
#  'afsi': 862880.6177606178,
#  'agen': 504033.0888030888,
#  'agii': 153387.56756756757,
#  'agys': 125250.61776061777,
#  'ahgp': 67731.81467181467,
#  'ahpi': 9122.818532818534,
#  'aimc': 166429.11196911198,
#  'ainv': 1780662.0463320464,
#  'aiq': 39758.146718146716,
#  'airm': 425482.50965250965,
#  'airt': 10077.335907335908,
#  'akam': 3720049.305019305,
#  'akrx': 962439.6525096525,
#  'alco': 14411.467181467182,
#  'algn': 884272.7027027027,
#  'algt': 200137.41312741314,
#  'alks': 1101872.3552123553,
#  'allt': 204833.08880308882,
#  'alny': 557952.5096525097,
#  'alog': 89872.58687258688,
#  'alot': 5993.204633204633,
#  'alqa': 44051.62162162162,
#  'alsk': 422474.9806949807,
#  'alxn': 1895603.9382239382,
#  'amag': 516020.8108108108,
#  'amat': 17738006.679536678,
#  'amd': 24757016.94980695,
#  'amed': 520495.7915057915,
#  'amgn': 6412205.173745174,
#  'amkr': 1962583.8223938225,
#  'amnb': 12595.289575289575,
#  'amot': 28585.366795366794,
#  'amrb': 9668.996138996139,
#  'amri': 244289.45945945947,
#  'amrn': 2131168.223938224,
#  'amsc': 85252.89575289575,
#  'amsf': 106570.27027027027,
#  'amswa': 71115.36679536679,
#  'amtd': 3952669.806949807,
#  'amwd': 102757.18146718146,
#  'amzn': 5974108.532818533,
#  'anat': 27090.42471042471,
#  'ancx': 19257.220077220078,
#  'ande': 304671.08108108107,
#  'ango': 179255.48262548263,
#  'anik': 118129.49806949806,
#  'anip': 107442.77992277993,
#  'anss': 543641.2355212355,
#  'aobc': 1420790.9652509652,
#  'apdn': 50195.67567567567,
#  'aplp': 117893.55212355213,
#  'apog': 255130.8494208494,
#  'apps': 107844.55598455599,
#  'apri': 256304.05405405405,
#  'apwc': 5846.061776061776,
#  'aray': 715858.9083820663,
#  'arcb': 457669.6525096525,
#  'arcc': 1618264.6718146717,
#  'arci': 20820.50193050193,
#  'arcw': 24244.362934362933,
#  'ardm': 9891.853281853282,
#  'arii': 164955.2895752896,
#  'aris': 13280.579150579151,
#  'arkr': 5397.876447876448,
#  'arlp': 226772.7413127413,
#  'arlz': 393096.8725868726,
#  'arna': 4344525.791505791,
#  'arow': 26645.366795366794,
#  'arql': 355122.2393822394,
#  'arrs': 1859118.8803088802,
#  'arry': 1253155.3667953669,
#  'artna': 16956.332046332045,
#  'artw': 15555.096525096526,
#  'artx': 189822.43243243243,
#  'arwr': 587790.6177606178,
#  'asfi': 57556.138996138994,
#  'asml': 2077267.6447876447,
#  'asna': 2170323.281853282,
#  'asrv': 19046.679536679538,
#  'asrvp': 3391.5830115830117,
#  'astc': 98270.7722007722,
#  'aste': 163945.05791505793,
#  'asur': 21848.262548262548,
#  'asys': 101983.8223938224,
#  'atax': 100231.9305019305,
#  'atec': 25110.23166023166,
#  'atlc': 184389.69111969112,
#  'atlo': 9871.312741312742,
#  'atni': 61553.01158301158,
#  'atrc': 101246.138996139,
#  'atri': 4211.042471042471,
#  'atro': 133282.58687258686,
#  'atrs': 774929.9613899614,
#  'atsg': 305745.32818532817,
#  'attu': 33671.5444015444,
#  'atvi': 9792519.536679536,
#  'aubn': 2249.073359073359,
#  'audc': 171067.83783783784,
#  'avav': 235268.25766395032,
#  'avdl': 193291.62162162163,
#  'avhi': 50917.065637065636,
#  'avir': 69071.31274131274,
#  'avnw': 25692.471042471043,
#  'awre': 39030.0,
#  'axas': 1050191.0038610038,
#  'axdx': 96071.77606177607,
#  'axgn': 36177.644787644786,
#  'axti': 236029.42084942086,
#  'azpn': 533115.9459459459,
#  'baby': 258983.62934362935,
#  'banf': 26178.91891891892,
#  'banfp': 1307.4903474903474,
#  'banr': 109445.48262548262,
#  'basi': 22256.332046332045,
#  'bbby': 3213463.397683398,
#  'bbgi': 10268.764478764479,
#  'bbh': 232690.3861003861,
#  'bbox': 97324.40154440154,
#  'bbry': 18719564.942084942,
#  'bbsi': 66179.69111969112,
#  'bcbp': 6359.69111969112,
#  'bcli': 70003.28185328185,
#  'bcor': 393857.3745173745,
#  'bcpc': 122519.5752895753,
#  'bcrx': 806484.2084942085,
#  'bde': 103194.2471042471,
#  'bdge': 20277.95366795367,
#  'bdsi': 445380.5791505792,
#  'bebe': 55543.51351351351,
#  'becn': 539912.9343629343,
#  'belfa': 3041.2355212355214,
#  'belfb': 36338.53281853282,
#  'bfin': 48722.66409266409,
#  'bgcp': 842065.1737451737,
#  'bgfv': 198908.57142857142,
#  'bidu': 14979788.764478764,
#  'biib': 2418686.718146718,
#  'biol': 223254.5945945946,
#  'bios': 667363.359073359,
#  'bjri': 321006.0617760618,
#  'bkmu': 167983.35907335908,
#  'bksc': 2214.285714285714,
#  'bldp': 955466.2548262548,
#  'bldr': 465452.77992277994,
#  'blfs': 38422.779922779926,
#  'blkb': 242526.5637065637,
#  'bmra': 1509.0733590733591,
#  'bmrc': 11940.61776061776,
#  'bmrn': 1460901.0424710424,
#  'bmtc': 31035.637065637067,
#  'bncn': 48480.50193050193,
#  'bnso': 25424.440154440155,
#  'bobe': 285938.64864864864,
#  'boch': 14746.409266409266,
#  'bofi': 504740.61776061775,
#  'bokf': 142544.2084942085,
#  'bont': 260978.22393822393,
#  'boom': 156235.44401544402,
#  'bosc': 31330.23166023166,
#  'botj': 1336.949806949807,
#  'bpop': 796606.0231660232,
#  'bpopn': 6936.563706563707,
#  'brcd': 9177569.536679536,
#  'brew': 52626.21621621621,
#  'brid': 2353.706563706564,
#  'brkl': 367152.04633204633,
#  'brkr': 757335.7528957529,
#  'brks': 453626.6795366795,
#  'bset': 42286.98841698842,
#  'bsf': 10017.722007722008,
#  'bsqr': 60565.79150579151,
#  'bsrr': 25103.0888030888,
#  'bstc': 24314.440154440155,
#  'buse': 56032.66409266409,
#  'bvsn': 42946.98841698842,
#  'bwen': 81933.32046332046,
#  'bwina': 677.8764478764479,
#  'bwinb': 21028.72586872587,
#  'bwld': 506982.5482625483,
#  'bybk': 4884.864864864865,
#  'byfc': 5187.2972972972975,
#  'ca': 3778223.6293436293,
#  'caas': 158379.03474903476,
#  'cac': 27063.667953667955,
#  'cacb': 50363.12741312741,
#  'cacc': 67477.02702702703,
#  'cake': 1116720.2702702703,
#  'cald': 290199.0733590734,
#  'call': 185475.59845559846,
#  'calm': 557183.7837837838,
#  'camp': 299970.7335907336,
#  'camt': 140174.40154440154,
#  'capr': 10261.67056986729,
#  'car': 2076896.0231660232,
#  'cart': 2160.6949806949806,
#  'carv': 2137.2972972972975,
#  'casc': 648725.9459459459,
#  'cash': 17979.49806949807,
#  'casi': 42449.72972972973,
#  'casm': 27250.42471042471,
#  'cass': 21874.671814671816,
#  'casy': 412956.44787644787,
#  'caty': 544319.8841698841,
#  'cbak': 111181.81467181467,
#  'cban': 3468.3011583011585,
#  'cbfv': 1261.6216216216217,
#  'cbio': 20758.68725868726,
#  'cbli': 48962.393822393824,
#  'cbmx': 26132.393822393824,
#  'cbrl': 370494.01544401544,
#  'cbsh': 510342.5482625483,
#  'ccbg': 29288.22393822394,
#  'ccmp': 185783.62934362935,
#  'ccne': 17134.980694980695,
#  'ccoi': 463522.1621621622,
#  'ccrn': 194633.74517374518,
#  'ccur': 39143.55212355212,
#  'cdns': 3437799.189189189,
#  'cdor': 2642.741312741313,
#  'cdti': 48131.35135135135,
#  'cdzi': 64786.75675675676,
#  'cece': 92117.60617760618,
#  'ceco': 1092216.7567567567,
#  'celg': 7086173.3590733595,
#  'cemi': 21465.212355212356,
#  'cent': 175352.20077220077,
#  'centa': 265020.68562524347,
#  'cenx': 2094789.111969112,
#  'cern': 2736305.4826254826,
#  'cers': 594144.555984556,
#  'cetv': 429662.2393822394,
#  'ceva': 145691.00386100388,
#  'cfbk': 9034.864864864865,
#  'cfcb': 1414.6774816531479,
#  'cffi': 5917.181467181467,
#  'cffn': 652601.5057915058,
#  'cfnb': 4137.876447876448,
#  'cfnl': 126220.0,
#  'cgen': 156215.7528957529,
#  'cgnt': 25629.38223938224,
#  'cgnx': 541141.0424710425,
#  'cgo': 28304.092664092663,
#  'chci': 19030.386100386102,
#  'chco': 66494.71042471043,
#  'chdn': 53524.32432432433,
#  'chfc': 118940.23166023166,
#  'chfn': 33708.61003861004,
#  'chi': 210559.6138996139,
#  'chke': 52745.984555984556,
#  'chkp': 1838837.4903474904,
#  'chmg': 3231.3127413127413,
#  'chnr': 59754.59459459459,
#  'chrw': 1617904.6718146717,
#  'chscp': 13814.169884169884,
#  'chy': 213358.80308880308,
#  'cidm': 29690.34749034749,
#  'cigi': 45521.853281853284,
#  'cinf': 927110.7722007722,
#  'civb': 6788.030888030888,
#  'cizn': 2548.108108108108,
#  'clbs': 16767.799227799227,
#  'clct': 33276.21621621621,
#  'cldx': 1179632.7799227799,
#  'clfd': 60627.95366795367,
#  'clmt': 312091.5444015444,
#  'clrb': 84380.69498069499,
#  'clro': 15704.671814671814,
#  'clsn': 226230.15444015444,
#  'club': 125556.5250965251,
#  'clwt': 13665.714285714286,
#  'cmco': 110934.09266409266,
#  'cmcsa': 34337459.69111969,
#  'cmct': 4460.2316602316605,
#  'cme': 3102017.2972972975,
#  'cmls': 619676.6795366795,
#  'cmpr': 543243.7065637065,
#  'cmtl': 269349.8069498069,
#  'cnbka': 5381.814671814672,
#  'cnit': 138948.76447876447,
#  'cnmd': 179933.51351351352,
#  'cnob': 42501.35135135135,
#  'cnsl': 205787.56756756757,
#  'cntf': 50532.355212355214,
#  'cnty': 78942.81853281854,
#  'cnxn': 64599.57528957529,
#  'cobz': 106686.02316602317,
#  'cohr': 162714.6332046332,
#  'cohu': 97412.3166023166,
#  'coke': 29195.444015444016,
#  'colb': 224761.5057915058,
#  'colm': 368995.444015444,
#  'conn': 530900.9266409266,
#  'cool': 19986.409266409268,
#  'core': 263304.0540540541,
#  'cort': 247523.861003861,
#  'cost': 3242085.4054054054,
#  'cown': 469422.7027027027,
#  'cpah': 1980.4156674660271,
#  'cpla': 155222.50965250965,
#  'cplp': 335643.87351778656,
#  'cprt': 872649.5752895753,
#  'cprx': 519350.7722007722,
#  'cpsh': 5804.003371260009,
#  'cpsi': 116006.02316602317,
#  'cpss': 77826.64092664093,
#  'cpst': 187931.66023166024,
#  'crai': 64803.74517374517,
#  'cray': 319937.6833976834,
#  'crds': 5209.6138996139,
#  'cree': 2205290.308880309,
#  'creg': 11223.397683397683,
#  'cresy': 119071.35135135135,
#  'cris': 493092.97297297296,
#  'crme': 86247.06563706564,
#  'crmt': 77179.5752895753,
#  'crnt': 337920.7722007722,
#  'crox': 2677406.061776062,
#  'crtn': 16739.38223938224,
#  'crus': 1981126.9111969112,
#  'crvl': 80643.28185328185,
#  'crws': 17826.795366795366,
#  'crzo': 1010127.0656370657,
#  'csbk': 46853.861003861006,
#  'csbr': 8801.362397820163,
#  'csco': 45224781.428571425,
#  'csfl': 94995.83011583012,
#  'csgp': 177594.94208494207,
#  'csgs': 300707.2586872587,
#  'csii': 153592.7027027027,
#  'csiq': 1927593.745173745,
#  'cspi': 12143.513513513513,
#  'csq': 400966.0617760618,
#  'cswc': 40461.08108108108,
#  'csx': 11931650.617760617,
#  'ctas': 979926.1776061776,
#  'ctbi': 49189.49806949807,
#  'ctg': 54884.32432432433,
#  'cthr': 56900.3861003861,
#  'ctib': 13332.895752895753,
#  'ctic': 1071086.3706563707,
#  'ctrn': 161079.88416988417,
#  'ctrp': 2776085.3667953666,
#  'ctsh': 6460113.05019305,
#  'ctws': 25974.015444015444,
#  'ctxs': 3333962.3166023167,
#  'cuba': 53780.772200772204,
#  'cui': 44911.35135135135,
#  'cunb': 15430.849420849421,
#  'cur': 407178.6956521739,
#  'cutr': 105842.47104247104,
#  'cvbf': 673397.1042471043,
#  'cvco': 40272.393822393824,
#  'cvcy': 9749.305019305019,
#  'cvgi': 181611.42857142858,
#  'cvgw': 83099.38223938223,
#  'cvlt': 523583.9768339768,
#  'cvly': 4994.015444015444,
#  'cvti': 75368.26254826254,
#  'cvv': 30440.54054054054,
#  'cwbc': 4858.648648648648,
#  'cwco': 84308.37837837837,
#  'cwst': 168939.38223938225,
#  'cy': 7870053.281853282,
#  'cyan': 14854.517374517374,
#  'cybe': 24161.58301158301,
#  'cycc': 49615.019305019305,
#  'cyccp': 1690.7722007722007,
#  'cyrn': 70347.99227799228,
#  'cyrx': 10998.8416988417,
#  'cytk': 232239.03474903476,
#  'cytr': 578542.084942085,
#  'cytx': 70441.1583011583,
#  'czfc': 1691.003861003861,
#  'cznc': 19318.76447876448,
#  'czwi': 7033.822393822394,
#  'daio': 19625.830115830115,
#  'dakt': 285820.88803088805,
#  'dave': 35781.23552123552,
#  'dcom': 149193.32046332047,
#  'dcth': 240321.85328185328,
#  'denn': 625252.2393822394,
#  'depo': 818343.2432432432,
#  'dest': 84935.17374517374,
#  'dfbg': 14915.675675675675,
#  'dgas': 10327.142857142857,
#  'dgica': 27233.783783783783,
#  'dgicb': 509.72972972972974,
#  'dgii': 110939.07335907336,
#  'dhil': 8233.204633204634,
#  'diod': 339167.87644787645,
#  'disca': 3629313.243243243,
#  'discb': 837.6061776061777,
#  'dish': 2783090.2316602315,
#  'djco': 1364.8648648648648,
#  'dlhc': 12878.918918918918,
#  'dltr': 3526729.3822393822,
#  'dmlp': 54844.05405405405,
#  'dmrc': 52071.51253918495,
#  'dnbf': 1960.4633204633205,
#  'dorm': 147053.35907335908,
#  'dox': 1047560.8108108108,
#  'drad': 64495.90733590734,
#  'dram': 34773.24324324324,
#  'drrx': 427490.23166023166,
#  'drys': 831780.694980695,
#  'dsgx': 23805.598455598454,
#  'dspg': 120240.81081081081,
#  'dswl': 23199.84555984556,
#  'dtrm': 6991.081081081081,
#  'dvax': 325822.89575289574,
#  'dvcr': 14741.505791505791,
#  'dwaq': 5202.084942084942,
#  'dwch': 48729.45945945946,
#  'dwsn': 39517.91505791506,
#  'dxcm': 550840.888030888,
#  'dxpe': 142762.47104247104,
#  'dxtr': 30068.14671814672,
#  'dxyn': 38717.25868725869,
#  'dynt': 8973.011583011583,
#  'dysl': 20130.23166023166,
#  'dzsi': 166444.2084942085,
#  'ea': 5209939.420849421,
#  'ebay': 29059822.548262548,
#  'ebix': 439481.6988416988,
#  'ebtc': 8725.675675675675,
#  'ecol': 116783.51351351352,
#  'ecpg': 199684.05405405405,
#  'edap': 134932.81853281852,
#  'edgw': 24166.949806949808,
#  'educ': 7668.416988416989,
#  'eeft': 358073.7837837838,
#  'eei': 5139.111969111969,
#  'efii': 341202.3552123552,
#  'efsc': 43305.21235521235,
#  'egan': 40375.94594594595,
#  'egbn': 62922.50965250965,
#  'eght': 628056.1776061776,
#  'egle': 35428.10810810811,
#  'egt': 18746.332046332045,
#  'ehth': 229180.30888030888,
#  'elgx': 500472.08494208497,
#  'elon': 22741.04247104247,
#  'elos': 170273.0115830116,
#  'else': 4009.034749034749,
#  'eltk': 30402.934362934364,
#  'emcf': 637.3745173745174,
#  'emci': 31905.096525096524,
#  'emitf': 3671.4671814671815,
#  'emkr': 283143.7837837838,
#  'eml': 11983.976833976834,
#  'emms': 47743.05019305019,
#  'endp': 2534224.3243243243,
#  'eng': 117659.5752895753,
#  'entg': 1012974.4787644788,
#  'epay': 195480.15444015444,
#  'eqfn': 1484.5559845559847,
#  'eqix': 872987.5675675676,
#  'eric': 5398251.66023166,
#  'esbk': 1612.5096525096526,
#  'esca': 14486.988416988417,
#  'esgr': 24012.12355212355,
#  'esio': 140898.26254826254,
#  'eslt': 19338.262548262548,
#  'esnd': 331482.12355212355,
#  'esrx': 5430109.884169884,
#  'essa': 34160.07123070835,
#  'esxb': 23855.250965250965,
#  'etfc': 3887712.1621621624,
#  'evbs': 8042.625482625483,
#  'evep': 278799.6138996139,
#  'evlv': 333925.21235521237,
#  'evol': 34586.87258687259,
#  'ewbc': 1135536.332046332,
#  'exac': 36801.312741312744,
#  'exas': 1080465.1351351351,
#  'exel': 2535425.4826254826,
#  'exfo': 52098.49420849421,
#  'exls': 145809.6138996139,
#  'expd': 1822973.4749034748,
#  'expe': 2409068.494208494,
#  'expo': 117495.71428571429,
#  'extr': 903672.084942085,
#  'ezpw': 495889.11196911195,
#  'falc': 194740.4633204633,
#  'farm': 36534.015444015444,
#  'faro': 134904.90347490346,
#  'fast': 2687156.3706563707,
#  'fbiz': 12641.621621621622,
#  'fbms': 2726.7567567567567,
#  'fbnc': 41292.04633204633,
#  'fbss': 1549.2277992277993,
#  'fcap': 840.7335907335907,
#  'fcco': 3558.6486486486488,
#  'fccy': 4768.841698841698,
#  'fcnca': 16141.196911196912,
#  'fdef': 22811.5444015444,
#  'feim': 12953.011583011583,
#  'fele': 243712.277992278,
#  'ffbc': 228614.90347490346,
#  'ffhl': 68737.52895752896,
#  'ffic': 95212.39382239382,
#  'ffin': 229987.52895752896,
#  'ffiv': 1824256.3706563707,
#  'ffkt': 16411.467181467182,
#  'fhco': 91308.68725868726,
#  'finl': 937734.6718146718,
#  'fisi': 30497.490347490348,
#  'fisv': 2120938.1467181467,
#  'fizz': 75639.92277992278,
#  'flex': 6136054.633204633,
#  'flic': 23145.057915057914,
#  'flir': 1321256.5250965252,
#  'fll': 43066.87258687259,
#  'flws': 231783.12741312743,
#  'flxs': 14914.285714285714,
#  'fmbi': 503978.0308880309}

# %%
# Company with biggest average volumes
max(volume_avg, key=volume_avg.get)
# Out:
# 'aapl'

# %% [markdown]
# It can be seen that Apple.inc (aapl) has the biggest average volume.

# %% [markdown]
# Now that we've computed some aggregates, we can work on finding the most traded stock each day.

# %%
transformed2 = {}
for day in transformed['aapl']['date']:
    transformed2[day] = {}
    for company in content.keys():
        dates = transformed[company]['date']
        if day not in dates:
            transformed2[day][company] = 0
        else:
            date_index = dates.index(day)
            transformed2[day][company] = int(transformed[company]['volume'][date_index])

#sort the dict

for day in transformed2:
    transformed2[day] = sorted(transformed2[day], key=transformed2[day].get, reverse=True)
    transformed2[day] = transformed2[day][0]
# Out:
# 'aapl'

# %%
transformed2
# Out:
# {'2007-01-03': 'aapl',
#  '2007-01-04': 'aapl',
#  '2007-01-05': 'aapl',
#  '2007-01-08': 'aapl',
#  '2007-01-09': 'aapl',
#  '2007-01-10': 'aapl',
#  '2007-01-11': 'aapl',
#  '2007-01-12': 'aapl',
#  '2007-01-16': 'aapl',
#  '2007-01-17': 'aapl',
#  '2007-01-18': 'aapl',
#  '2007-01-19': 'aapl',
#  '2007-01-22': 'aapl',
#  '2007-01-23': 'aapl',
#  '2007-01-24': 'aapl',
#  '2007-01-25': 'aapl',
#  '2007-01-26': 'aapl',
#  '2007-01-29': 'aapl',
#  '2007-01-30': 'aapl',
#  '2007-01-31': 'aapl',
#  '2007-02-01': 'aapl',
#  '2007-02-02': 'aapl',
#  '2007-02-05': 'aapl',
#  '2007-02-06': 'aapl',
#  '2007-02-07': 'aapl',
#  '2007-02-08': 'aapl',
#  '2007-02-09': 'aapl',
#  '2007-02-12': 'aapl',
#  '2007-02-13': 'aapl',
#  '2007-02-14': 'aapl',
#  '2007-02-15': 'bidu',
#  '2007-02-16': 'aapl',
#  '2007-02-20': 'aapl',
#  '2007-02-21': 'aapl',
#  '2007-02-22': 'aapl',
#  '2007-02-23': 'aapl',
#  '2007-02-26': 'aapl',
#  '2007-02-27': 'aapl',
#  '2007-02-28': 'aapl',
#  '2007-03-01': 'aapl',
#  '2007-03-02': 'aapl',
#  '2007-03-05': 'aapl',
#  '2007-03-06': 'aapl',
#  '2007-03-07': 'aapl',
#  '2007-03-08': 'cy',
#  '2007-03-09': 'aapl',
#  '2007-03-12': 'aapl',
#  '2007-03-13': 'aapl',
#  '2007-03-14': 'aapl',
#  '2007-03-15': 'aapl',
#  '2007-11-29': 'aapl',
#  '2007-11-30': 'aapl',
#  '2007-12-03': 'aapl',
#  '2007-12-04': 'aapl',
#  '2007-12-05': 'cmcsa',
#  '2007-12-06': 'aapl',
#  '2007-12-07': 'aapl',
#  '2007-12-10': 'aapl',
#  '2007-12-11': 'aapl',
#  '2007-12-12': 'aapl',
#  '2007-12-13': 'aapl',
#  '2007-12-14': 'aapl',
#  '2007-12-17': 'aapl',
#  '2007-12-18': 'aapl',
#  '2007-12-19': 'aapl',
#  '2007-12-20': 'aapl',
#  '2007-12-21': 'aapl',
#  '2007-12-24': 'aapl',
#  '2007-12-26': 'aapl',
#  '2007-12-27': 'aapl',
#  '2007-12-28': 'aapl',
#  '2007-12-31': 'aapl',
#  '2008-01-02': 'aapl',
#  '2008-01-03': 'aapl',
#  '2008-01-04': 'aapl',
#  '2008-01-07': 'aapl',
#  '2008-01-08': 'aapl',
#  '2008-01-09': 'aapl',
#  '2008-01-10': 'aapl',
#  '2008-01-11': 'aapl',
#  '2008-01-14': 'aapl',
#  '2008-01-15': 'aapl',
#  '2008-01-16': 'aapl',
#  '2008-01-17': 'aapl',
#  '2008-01-18': 'aapl',
#  '2008-01-22': 'aapl',
#  '2008-01-23': 'aapl',
#  '2008-01-24': 'aapl',
#  '2008-01-25': 'aapl',
#  '2008-01-28': 'aapl',
#  '2008-01-29': 'aapl',
#  '2008-01-30': 'aapl',
#  '2008-01-31': 'aapl',
#  '2008-02-01': 'aapl',
#  '2008-02-04': 'aapl',
#  '2008-02-05': 'aapl',
#  '2008-02-06': 'aapl',
#  '2008-02-07': 'aapl',
#  '2008-02-08': 'aapl',
#  '2008-02-11': 'aapl',
#  '2008-02-12': 'aapl',
#  '2008-02-13': 'aapl',
#  '2008-02-14': 'aapl',
#  '2008-02-15': 'aapl',
#  '2008-02-19': 'aapl',
#  '2008-02-20': 'aapl',
#  '2008-02-21': 'aapl',
#  '2008-02-22': 'aapl',
#  '2008-02-25': 'aapl',
#  '2008-02-26': 'aapl',
#  '2008-02-27': 'aapl',
#  '2008-02-28': 'aapl',
#  '2008-02-29': 'aapl',
#  '2008-03-03': 'aapl',
#  '2008-03-04': 'aapl',
#  '2008-03-05': 'aapl',
#  '2008-03-06': 'aapl',
#  '2008-03-07': 'aapl',
#  '2008-03-10': 'aapl',
#  '2008-03-11': 'aapl',
#  '2008-03-12': 'aapl',
#  '2008-03-13': 'aapl',
#  '2008-03-14': 'aapl',
#  '2008-03-17': 'aapl',
#  '2008-03-18': 'aapl',
#  '2008-03-19': 'aapl',
#  '2008-03-20': 'aapl',
#  '2008-03-24': 'aapl',
#  '2008-03-25': 'aapl',
#  '2008-03-26': 'aapl',
#  '2008-03-27': 'aapl',
#  '2008-03-28': 'aapl',
#  '2008-03-31': 'aapl',
#  '2008-04-01': 'aapl',
#  '2008-04-02': 'aapl',
#  '2008-04-03': 'aapl',
#  '2008-04-04': 'aapl',
#  '2008-04-07': 'aapl',
#  '2008-04-08': 'aapl',
#  '2008-04-09': 'aapl',
#  '2010-01-19': 'aapl',
#  '2010-01-20': 'aapl',
#  '2010-01-21': 'ebay',
#  '2010-01-22': 'aapl',
#  '2010-01-25': 'aapl',
#  '2010-01-26': 'aapl',
#  '2010-01-27': 'aapl',
#  '2010-01-28': 'aapl',
#  '2010-01-29': 'aapl',
#  '2010-02-01': 'aapl',
#  '2010-02-02': 'aapl',
#  '2010-02-03': 'aapl',
#  '2010-02-04': 'aapl',
#  '2010-02-05': 'aapl',
#  '2010-02-08': 'aapl',
#  '2010-02-09': 'aapl',
#  '2010-02-10': 'aapl',
#  '2010-02-11': 'aapl',
#  '2010-02-12': 'aapl',
#  '2010-02-16': 'aapl',
#  '2010-02-17': 'aapl',
#  '2010-02-18': 'aapl',
#  '2010-02-19': 'aapl',
#  '2010-02-22': 'aapl',
#  '2010-02-23': 'brcd',
#  '2010-02-24': 'aapl',
#  '2010-02-25': 'aapl',
#  '2010-02-26': 'aapl',
#  '2010-03-01': 'aapl',
#  '2010-03-02': 'aapl',
#  '2010-03-03': 'aapl',
#  '2010-03-04': 'aapl',
#  '2010-03-05': 'aapl',
#  '2010-03-08': 'csco',
#  '2010-03-09': 'aapl',
#  '2010-03-10': 'aapl',
#  '2010-03-11': 'aapl',
#  '2010-03-12': 'aapl',
#  '2010-03-15': 'aapl',
#  '2010-03-16': 'aapl',
#  '2010-03-17': 'aapl',
#  '2010-03-18': 'aapl',
#  '2010-03-19': 'aapl',
#  '2010-03-22': 'aapl',
#  '2010-03-23': 'aapl',
#  '2010-03-24': 'aapl',
#  '2010-03-25': 'aapl',
#  '2010-03-26': 'aapl',
#  '2010-03-29': 'aapl',
#  '2010-03-30': 'aapl',
#  '2010-03-31': 'aapl',
#  '2010-04-01': 'aapl',
#  '2010-04-05': 'aapl',
#  '2010-04-06': 'aapl',
#  '2010-04-07': 'aapl',
#  '2010-04-08': 'aapl',
#  '2010-04-09': 'aapl',
#  '2010-04-12': 'aapl',
#  '2010-04-13': 'aapl',
#  '2010-04-14': 'aapl',
#  '2010-04-15': 'aapl',
#  '2010-04-16': 'aapl',
#  '2010-04-19': 'aapl',
#  '2010-04-20': 'aapl',
#  '2010-04-21': 'aapl',
#  '2010-04-22': 'aapl',
#  '2010-04-23': 'aapl',
#  '2010-04-26': 'aapl',
#  '2010-04-27': 'aapl',
#  '2010-04-28': 'aapl',
#  '2010-04-29': 'aapl',
#  '2010-04-30': 'aapl',
#  '2010-05-03': 'aapl',
#  '2010-05-04': 'aapl',
#  '2010-05-05': 'aapl',
#  '2010-05-06': 'aapl',
#  '2010-05-07': 'aapl',
#  '2010-05-10': 'aapl',
#  '2010-05-11': 'aapl',
#  '2010-05-12': 'aapl',
#  '2010-05-13': 'aapl',
#  '2010-05-14': 'aapl',
#  '2010-05-17': 'aapl',
#  '2010-05-18': 'aapl',
#  '2010-05-19': 'aapl',
#  '2010-05-20': 'aapl',
#  '2010-05-21': 'aapl',
#  '2010-05-24': 'aapl',
#  '2010-05-25': 'aapl',
#  '2010-05-26': 'aapl',
#  '2010-05-27': 'aapl',
#  '2010-05-28': 'aapl',
#  '2010-06-01': 'aapl',
#  '2010-06-02': 'aapl',
#  '2010-06-03': 'aapl',
#  '2010-06-04': 'aapl',
#  '2010-06-07': 'aapl',
#  '2010-06-08': 'aapl',
#  '2010-06-09': 'aapl',
#  '2010-06-10': 'aapl',
#  '2010-06-11': 'aapl',
#  '2010-06-14': 'aapl',
#  '2010-06-15': 'aapl',
#  '2010-06-16': 'aapl',
#  '2010-06-17': 'aapl',
#  '2010-06-18': 'aapl',
#  '2010-06-21': 'aapl',
#  '2010-06-22': 'aapl',
#  '2010-06-23': 'aapl',
#  '2010-06-24': 'aapl',
#  '2010-06-25': 'aapl',
#  '2010-06-28': 'aapl',
#  '2010-06-29': 'aapl',
#  '2010-06-30': 'aapl',
#  '2010-07-01': 'aapl',
#  '2010-07-02': 'aapl',
#  '2010-07-06': 'aapl',
#  '2010-07-07': 'aapl',
#  '2010-07-08': 'aapl',
#  '2010-07-09': 'aapl',
#  '2010-07-12': 'aapl',
#  '2010-07-13': 'aapl',
#  '2010-07-14': 'aapl',
#  '2010-07-15': 'aapl',
#  '2010-07-16': 'aapl',
#  '2010-07-19': 'aapl',
#  '2010-07-20': 'aapl',
#  '2010-07-21': 'aapl',
#  '2010-07-22': 'aapl',
#  '2010-07-23': 'aapl',
#  '2010-07-26': 'aapl',
#  '2010-07-27': 'aapl',
#  '2010-07-28': 'aapl',
#  '2010-07-29': 'aapl',
#  '2010-07-30': 'aapl',
#  '2010-08-02': 'aapl',
#  '2010-08-03': 'aapl',
#  '2010-08-04': 'aapl',
#  '2010-08-05': 'aapl',
#  '2010-08-06': 'aapl',
#  '2010-08-09': 'aapl',
#  '2010-08-10': 'aapl',
#  '2010-08-11': 'aapl',
#  '2010-08-12': 'csco',
#  '2010-08-13': 'aapl',
#  '2010-08-16': 'csco',
#  '2010-08-17': 'aapl',
#  '2010-08-18': 'aapl',
#  '2010-08-19': 'aapl',
#  '2010-08-20': 'aapl',
#  '2010-08-23': 'aapl',
#  '2010-08-24': 'aapl',
#  '2010-08-25': 'aapl',
#  '2010-08-26': 'aapl',
#  '2010-08-27': 'aapl',
#  '2010-08-30': 'aapl',
#  '2010-08-31': 'aapl',
#  '2010-09-01': 'aapl',
#  '2010-09-02': 'aapl',
#  '2010-09-03': 'aapl',
#  '2010-09-07': 'aapl',
#  '2010-09-08': 'aapl',
#  '2010-09-09': 'aapl',
#  '2010-09-10': 'aapl',
#  '2010-09-13': 'aapl',
#  '2010-09-14': 'csco',
#  '2010-09-15': 'aapl',
#  '2010-09-16': 'aapl',
#  '2010-09-17': 'aapl',
#  '2010-09-20': 'aapl',
#  '2010-09-21': 'aapl',
#  '2010-09-22': 'aapl',
#  '2010-09-23': 'aapl',
#  '2010-09-24': 'aapl',
#  '2010-09-27': 'aapl',
#  '2010-09-28': 'aapl',
#  '2010-09-29': 'aapl',
#  '2010-09-30': 'aapl',
#  '2010-10-01': 'aapl',
#  '2010-10-04': 'aapl',
#  '2010-10-05': 'aapl',
#  '2010-10-06': 'aapl',
#  '2010-10-07': 'aapl',
#  '2010-10-08': 'aapl',
#  '2010-10-11': 'aapl',
#  '2010-10-12': 'aapl',
#  '2010-10-13': 'aapl',
#  '2010-10-14': 'aapl',
#  '2010-10-15': 'aapl',
#  '2010-10-18': 'aapl',
#  '2010-10-19': 'aapl',
#  '2010-10-20': 'aapl',
#  '2010-10-21': 'aapl',
#  '2010-10-22': 'aapl',
#  '2010-10-25': 'aapl',
#  '2010-10-26': 'aapl',
#  '2010-10-27': 'aapl',
#  '2010-10-28': 'aapl',
#  '2010-10-29': 'aapl',
#  '2010-11-01': 'aapl',
#  '2010-11-02': 'aapl',
#  '2010-11-03': 'aapl',
#  '2010-11-04': 'aapl',
#  '2010-11-05': 'aapl',
#  '2010-11-08': 'aapl',
#  '2010-11-09': 'aapl',
#  '2010-11-10': 'csco',
#  '2010-11-11': 'csco',
#  '2010-11-12': 'csco',
#  '2010-11-15': 'csco',
#  '2010-11-16': 'csco',
#  '2010-11-17': 'aapl',
#  '2010-11-18': 'aapl',
#  '2010-11-19': 'csco',
#  '2010-11-22': 'aapl',
#  '2010-11-23': 'aapl',
#  '2010-11-24': 'aapl',
#  '2010-11-26': 'aapl',
#  '2010-11-29': 'aapl',
#  '2010-11-30': 'aapl',
#  '2010-12-01': 'aapl',
#  '2010-12-02': 'aapl',
#  '2010-12-03': 'csco',
#  '2010-12-06': 'aapl',
#  '2010-12-07': 'aapl',
#  '2010-12-08': 'aapl',
#  '2010-12-09': 'csco',
#  '2010-12-10': 'aapl',
#  '2010-12-13': 'aapl',
#  '2010-12-14': 'aapl',
#  '2010-12-15': 'aapl',
#  '2010-12-16': 'aapl',
#  '2010-12-17': 'csco',
#  '2010-12-20': 'aapl',
#  ...}

# %% [markdown]
# Finally, we will find the most profitable stock. This can be done by:
# - Subtracting the initial price from the final price, then computing a percentage relative to the initial price. This will tell us how much our initial investment would have grown or shrunk.
# - Sorting all of the percentages.
# - Finding the stock that grew the most in the time period.

# %%
#percentage of change for each company
transformed3 = {}
for company in content.keys():
    start_price = float(content[company][1][2])
    end_price = float(content[company][-1][1])
    percentage = ((end_price - start_price) / start_price) * 100
    transformed3[company] = percentage
    
transformed3
# Out:
# {'aal': -17.92540207692341,
#  'aame': 24.193548387096772,
#  'aaon': 30.65607672516539,
#  'aapl': 64.36435698649157,
#  'aaww': 22.355824983299943,
#  'aaxn': 177.73584905660377,
#  'abax': 146.03419668044603,
#  'abcb': 54.8371917751045,
#  'abco': -12.861915128769205,
#  'abeo': 71.87500000000001,
#  'abio': -41.5188961156602,
#  'abmd': 749.0154922644163,
#  'abtl': 237.71428571428572,
#  'acad': 275.36556805399323,
#  'acet': 71.97231833910035,
#  'acfc': -56.96969696969697,
#  'acgl': 40.21610656873732,
#  'achc': 1330.0000666666667,
#  'achn': -77.90626902008522,
#  'aciw': -35.95574480503211,
#  'acls': 211.54499151103568,
#  'acnb': 48.73740883584017,
#  'acor': 5.113636363636355,
#  'acta': 36.54033041788146,
#  'actg': -62.313432835820905,
#  'acxm': 6.001562743569759,
#  'adbe': 219.22888459654013,
#  'adi': 131.97691770422108,
#  'admp': 7483.8389225948395,
#  'adp': 109.15846940765832,
#  'adra': -12.503754132852427,
#  'adrd': -30.070395574924568,
#  'adre': -8.695649675162434,
#  'adru': -32.95905439369041,
#  'adsk': 111.64163397387068,
#  'adtn': -16.37706342311034,
#  'adxs': 4461.111111111112,
#  'aegn': -15.747126436781619,
#  'aehr': -10.159362549800793,
#  'aeis': 243.70101117098858,
#  'aemd': 767.8571428571429,
#  'aey': -35.71428571428571,
#  'aezs': -27.710982725816425,
#  'afam': 8.136063348014854,
#  'afsi': 80.11560693641619,
#  'agen': 86.95276236293074,
#  'agii': 87.14286248979606,
#  'agys': -51.46043547530535,
#  'ahgp': 43.947095625635804,
#  'ahpi': -61.359223300970875,
#  'aimc': 171.50145772594752,
#  'ainv': -70.65120428189117,
#  'aiq': 97.54977029096477,
#  'airm': 54.23247446528946,
#  'airt': 112.34428086070214,
#  'akam': 9.616101379053307,
#  'akrx': 395.96899224806197,
#  'alco': -45.3307414268194,
#  'algn': 724.4810307802435,
#  'algt': 443.54720932485156,
#  'alks': 321.6617210682493,
#  'allt': -58.60262008733624,
#  'alny': 133.7156116383308,
#  'alog': 24.73479800681051,
#  'alot': 46.34146341463415,
#  'alqa': -26.794864927598333,
#  'alsk': -85.8459512837393,
#  'alxn': 193.47986201630715,
#  'amag': -61.36214926777507,
#  'amat': 107.53275109170306,
#  'amd': -36.30478087649402,
#  'amed': 59.78787878787878,
#  'amgn': 136.89902235861464,
#  'amkr': 19.402985074626848,
#  'amnb': 55.17240710463762,
#  'amot': 211.77327034883723,
#  'amrb': -37.912327697314794,
#  'amri': 45.037453183520604,
#  'amrn': 38.93805309734515,
#  'amsc': -32.15010141987829,
#  'amsf': 317.1502063185042,
#  'amswa': 55.049786628734,
#  'amtd': 130.19101047443004,
#  'amwd': 107.38974475828975,
#  'amzn': 2231.928619441572,
#  'anat': 1.6124756672292022,
#  'ancx': 189.80019978969506,
#  'ande': -11.979294895352439,
#  'ango': -28.57142857142857,
#  'anik': 228.8889037037037,
#  'anip': 1681.8998622293218,
#  'anss': 146.01156531791906,
#  'aobc': 104.7024952015355,
#  'apdn': 1549.6700659868025,
#  'aplp': -39.59259629629629,
#  'apog': 166.87118440036727,
#  'apps': -55.60975609756097,
#  'apri': 120.00000000000001,
#  'apwc': 0.7692307692307698,
#  'aray': -77.85714285714288,
#  'arcb': -32.22891566265061,
#  'arcc': -8.368205629277943,
#  'arci': -47.0,
#  'arcw': 3898.60048982856,
#  'ardm': 58.241758241758234,
#  'arii': 21.594871315632382,
#  'aris': 147.31707317073176,
#  'arkr': -24.164135309171105,
#  'arlp': -37.02953280169273,
#  'arlz': -90.47058823529412,
#  'arna': -88.65900383141762,
#  'arow': 33.19887087592024,
#  'arql': -82.32323232323233,
#  'arrs': 107.44260490894695,
#  'arry': -35.34883720930233,
#  'artna': 90.0262619436358,
#  'artw': -48.46153846153846,
#  'artx': -3.174603174603177,
#  'arwr': -64.15525114155251,
#  'asfi': -73.313687841726,
#  'asml': 432.8278052532967,
#  'asna': -83.38316958564715,
#  'asrv': -18.72427983539095,
#  'asrvp': 6.055780876494012,
#  'astc': 118.03278688524593,
#  'aste': 70.35047568257559,
#  'asur': 502.4390243902439,
#  'asys': -32.727272727272734,
#  'atax': -26.282051282051285,
#  'atec': -44.23589503265149,
#  'atlc': -93.24799196787149,
#  'atlo': 46.42857142857143,
#  'atni': 144.91469095271984,
#  'atrc': 113.53135313531352,
#  'atri': 506.3250724987322,
#  'atro': 80.35371629245385,
#  'atrs': 131.9672131147541,
#  'atsg': 137.12230215827338,
#  'attu': 473.8095238095238,
#  'atvi': 177.90433814944976,
#  'aubn': 13.187961688749109,
#  'audc': -28.99470899470899,
#  'avav': 11.440004000000002,
#  'avdl': -69.01639344262296,
#  'avhi': -79.40630746830692,
#  'avir': -91.20252147464508,
#  'avnw': 204.53620805616825,
#  'awre': -12.593984962406013,
#  'axas': -35.3896103896104,
#  'axdx': 1057.5,
#  'axgn': 1502.7397260273972,
#  'axti': 21.01910828025478,
#  'azpn': 430.6654496402879,
#  'baby': 134.73053085445923,
#  'banf': 64.04660070279266,
#  'banfp': 9.622266401590466,
#  'banr': 19.435876601121677,
#  'basi': -77.81818181818181,
#  'bbby': 0.15637477603270133,
#  'bbgi': 35.504201680672274,
#  'bbh': -36.05717137062752,
#  'bbox': -77.11724409335325,
#  'bbry': -93.21522565254328,
#  'bbsi': 133.00930262045648,
#  'bcbp': -8.45920897034495,
#  'bcli': 1449.9225038748066,
#  'bcor': -16.007905138339915,
#  'bcpc': 203.4388432564598,
#  'bcrx': -40.0,
#  'bde': -22.85714285714285,
#  'bdge': 37.291670833333335,
#  'bdsi': -45.33762057877813,
#  'bebe': -81.010101010101,
#  'becn': 156.45076882569776,
#  'belfa': -34.516132258064516,
#  'belfb': -35.91569535984917,
#  'bfin': -18.53521126760563,
#  'bgcp': 21.818181818181813,
#  'bgfv': -37.65330898010257,
#  'bidu': 46.87287717164616,
#  'biib': 456.1079414794631,
#  'biol': -84.98289415124682,
#  'bios': -59.598853868194844,
#  'bjri': 103.88588785046731,
#  'bkmu': -21.00909842845326,
#  'bksc': 26.865679531447718,
#  'bldp': -48.421052631578945,
#  'bldr': -17.50972762645914,
#  'blfs': 2799.9585720203995,
#  'blkb': 194.9347810796155,
#  'bmra': 464.99999999999994,
#  'bmrc': 83.1944361111111,
#  'bmrn': 448.6992832002854,
#  'bmtc': 64.07888375996644,
#  'bncn': 62.65061244979918,
#  'bnso': -55.18518518518519,
#  'bobe': 88.53224686314559,
#  'boch': -9.722222222222218,
#  'bofi': 257.43145743145743,
#  'bokf': 38.37463669142427,
#  'bont': -98.24863633369874,
#  'boom': -52.76008492569002,
#  'bosc': -19.521912350597603,
#  'botj': -21.195660739602097,
#  'bpop': 117.73206225680934,
#  'bpopn': -4.509803921568622,
#  'brcd': 49.63942307692306,
#  'brew': 135.57692307692307,
#  'brid': 87.5,
#  'brkl': 12.537764350453173,
#  'brkr': 195.73333333333335,
#  'brks': 48.90109890109889,
#  'bset': 69.79987871437237,
#  'bsf': -62.11180124223602,
#  'bsqr': 79.07801418439718,
#  'bsrr': -12.053871648017795,
#  'bstc': 1206.0000499999999,
#  'buse': 22.623782493366882,
#  'bvsn': 477.9220779220779,
#  'bwen': 312.30769230769226,
#  'bwina': -8.228350393700778,
#  'bwinb': -2.448653238546603,
#  'bwld': 186.92219866737693,
#  'bybk': -58.62470862470863,
#  'byfc': -83.9047619047619,
#  'ca': 37.917580820719344,
#  'caas': -62.529644268774696,
#  'cac': -8.910675187131266,
#  'cacb': -76.13380508201995,
#  'cacc': 477.08088814152455,
#  'cake': 149.1941901692184,
#  'cald': 212.59842519685043,
#  'call': 96.51162790697674,
#  'calm': 321.3973580786026,
#  'camp': 88.60163337250295,
#  'camt': -12.731481481481488,
#  'capr': 52.49999999999999,
#  'car': 31.055051883259267,
#  'cart': -62.05404995178919,
#  'carv': -77.98569635061251,
#  'casc': 194.7754594579266,
#  'cash': 187.24832507544716,
#  'casi': -24.84546737423727,
#  'casm': -82.81444582814446,
#  'cass': 78.30629089909267,
#  'casy': 374.67231289640597,
#  'caty': 4.798856459737266,
#  'cbak': -78.78787878787878,
#  'cban': -23.809523809523817,
#  'cbfv': 66.27566957628561,
#  'cbio': -41.93888303477345,
#  'cbli': -4.0000000000000036,
#  'cbmx': 442.16867469879514,
#  'cbrl': 254.88907424173837,
#  'cbsh': 11.721274001876045,
#  'ccbg': -41.20987904600623,
#  'ccmp': 108.49192629622686,
#  'ccne': 67.07142142857143,
#  'ccoi': 170.0729884383827,
#  'ccrn': -35.08211678832117,
#  'ccur': 172.37569060773478,
#  'cdns': 74.43023346303505,
#  'cdor': 54.178674351585,
#  'cdti': 48.34816815014835,
#  'cdzi': -33.33333333333333,
#  'cece': 0.7575757575757582,
#  'ceco': -62.35149528881606,
#  'celg': 115.2667888215762,
#  'cemi': 626.1904761904761,
#  'cent': -22.215361334156896,
#  'centa': 144.96551724137933,
#  'cenx': -73.55225205236299,
#  'cern': 28.70593732016366,
#  'cers': -29.510961214165267,
#  'cetv': -95.52259695644891,
#  'ceva': 441.9303797468354,
#  'cfbk': -69.72602739726027,
#  'cfcb': 28.49582834938955,
#  'cffi': 20.530129005744996,
#  'cffn': -62.285260236389426,
#  'cfnb': 23.282442748091594,
#  'cfnl': 171.81728862973765,
#  'cgen': 66.015625,
#  'cgnt': 21.21212121212121,
#  'cgnx': 238.8053367249233,
#  'cgo': -28.688524590163926,
#  'chci': -64.95722901596139,
#  'chco': 53.01703664316481,
#  'chdn': 267.68149021823206,
#  'chfc': 43.393397699501435,
#  'chfn': -62.54053356702142,
#  'chi': -45.43660582141095,
#  'chke': -81.29967230714522,
#  'chkp': 368.63635454545454,
#  'chmg': 16.423009864820536,
#  'chnr': -70.51282051282051,
#  'chrw': 79.10058698224853,
#  'chscp': 16.425863742428277,
#  'chy': -34.43478260869565,
#  'cidm': -84.15051311288484,
#  'cigi': 109.6915022964153,
#  'cinf': 57.88313375449322,
#  'civb': 11.370557798448834,
#  'cizn': 12.527964205816541,
#  'clbs': 464.99999999999994,
#  'clct': 88.5245827123696,
#  'cldx': 145.4644012221703,
#  'clfd': 1015.1079136690647,
#  'clmt': -91.14956758591923,
#  'clrb': 116.6668923613462,
#  'clro': 126.74418604651163,
#  'clsn': -84.02061855670104,
#  'club': -80.66465139967683,
#  'clwt': -6.333392963342326,
#  'cmco': 18.056222010481186,
#  'cmcsa': -12.22274629016644,
#  'cmct': 7.939639107611549,
#  'cme': -77.23854554486817,
#  'cmls': -97.52144899904671,
#  'cmpr': 160.18045714285714,
#  'cmtl': -65.11140418813083,
#  'cnbka': 134.61540419836646,
#  'cnit': -87.81818181818181,
#  'cnmd': 98.83570078328155,
#  'cnob': 43.61700955982358,
#  'cnsl': 15.300290753098182,
#  'cntf': -77.79799818016379,
#  'cnty': -35.71428571428571,
#  'cnxn': 89.33333333333331,
#  'cobz': -26.01182355616189,
#  'cohr': 517.7454973160719,
#  'cohu': -11.712593503937015,
#  'coke': 202.22902101149506,
#  'colb': 7.152994606869155,
#  'colm': 5.224551891654169,
#  'conn': -44.255319148936174,
#  'cool': 808.129985548437,
#  'core': -8.343268523740504,
#  'cort': 780.952380952381,
#  'cost': 218.0881037708755,
#  'cown': -37.293726416488745,
#  'cpah': 502.56410256410254,
#  'cpla': 244.44886803319216,
#  'cplp': -86.53846153846155,
#  'cprt': -1.2541221536013847,
#  'cprx': -65.8,
#  'cpsh': -3.448275862068969,
#  'cpsi': -20.135813998695422,
#  'cpss': -28.461538461538456,
#  'cpst': -35.48387096774193,
#  'crai': -30.45540549420483,
#  'cray': 60.416666666666664,
#  'crds': 239.81481481481478,
#  'cree': 39.39046229962405,
#  'creg': 678.9473684210526,
#  'cresy': 19.463797617710366,
#  'cris': 108.73015873015872,
#  'crme': -71.51841868823001,
#  'crmt': 201.25001666666668,
#  'crnt': -42.727272727272734,
#  'crox': -85.78374590839883,
#  'crtn': -49.68944099378882,
#  'crus': 801.2912482065998,
#  'crvl': -13.637297466364707,
#  'crws': 81.17647058823529,
#  'crzo': -2.363573166492874,
#  'csbk': 32.21306320883175,
#  'csbr': 450.98039215686276,
#  'csco': 18.75456004204515,
#  'csfl': 13.987676623992416,
#  'csgp': 283.84586328269734,
#  'csgs': 36.45246011076813,
#  'csii': 405.60422066549904,
#  'csiq': 22.222222222222218,
#  'cspi': 32.25,
#  'csq': -27.752736638763675,
#  'cswc': -87.33124117219401,
#  'csx': 35.87456456057062,
#  'ctas': 209.92944304435483,
#  'ctbi': 5.409333886211109,
#  'ctg': 18.125000000000004,
#  'cthr': -88.5143570536829,
#  'ctib': 20.71713147410359,
#  'ctic': 123.20454320692996,
#  'ctrn': -54.781732152870745,
#  'ctrp': -22.84126825396826,
#  'ctsh': -24.462743848446063,
#  'ctws': 137.06322702064452,
#  'ctxs': 205.7530304140711,
#  'cuba': -56.139240506329116,
#  'cui': 1525.1625162516252,
#  'cunb': 114.70588235294117,
#  'cur': 58.22784810126581,
#  'cutr': -26.265590608950845,
#  'cvbf': 55.731523378582196,
#  'cvco': 221.20031001943264,
#  'cvcy': 26.71187118644067,
#  'cvgi': -68.31818181818183,
#  'cvgw': 527.5071346704871,
#  'cvlt': 152.74999499999998,
#  'cvly': 27.576818533230735,
#  'cvti': 51.88431200701138,
#  'cvv': 91.66666666666666,
#  'cwbc': -36.835522201375866,
#  'cwco': -54.29029854489581,
#  'cwst': 14.634146341463406,
#  'cy': -20.61257410842708,
#  'cyan': 108.1081081081081,
#  'cybe': 86.56716417910447,
#  'cycc': -14.45631623860548,
#  'cyccp': 37.383177570093466,
#  'cyrn': 61.41897515486377,
#  'cyrx': 670.3081232492998,
#  'cytk': 24.336137615872023,
#  'cytr': -77.20145827763236,
#  'cytx': -84.62665389751659,
#  'czfc': 14.092313846153848,
#  'cznc': 5.909076735538484,
#  'czwi': 44.376278118609406,
#  'daio': 37.57062146892656,
#  'dakt': -75.5992465499799,
#  'dave': -76.80722891566265,
#  'dcom': 42.400561079545454,
#  'dcth': -98.36512261580381,
#  'denn': 156.0924369747899,
#  'depo': 250.57471264367814,
#  'dest': -90.9658942983598,
#  'dfbg': 192.8575612250874,
#  'dgas': 21.571767378838523,
#  'dgica': -9.872778625954194,
#  'dgicb': -12.888888888888891,
#  'dgii': -12.824207492795397,
#  'dhil': 134.68044833401223,
#  'diod': -34.81066832949954,
#  'disca': 76.25231910946195,
#  'discb': 71.14921748438402,
#  'dish': 54.507234021215076,
#  'djco': 409.8522418646425,
#  'dlhc': 284.9206349206349,
#  'dltr': 152.97992930457454,
#  'dmlp': -22.480620155038757,
#  'dmrc': 215.81922033898303,
#  'dnbf': 73.73741893685232,
#  'dorm': 621.2569408502773,
#  'dox': 56.22904307454216,
#  'drad': 24.697336561743352,
#  'dram': -72.62183515374929,
#  'drrx': -80.58035714285714,
#  'drys': -89.2777742037025,
#  'dsgx': 506.3829521276596,
#  'dspg': -43.60036572745699,
#  'dswl': -82.65486725663716,
#  'dtrm': 108.88888888888889,
#  'dvax': -39.41048034934498,
#  'dvcr': -35.4551241247613,
#  'dwaq': 56.532472464869,
#  'dwch': 171.53558052434457,
#  'dwsn': -36.02428908346662,
#  'dxcm': 655.4216666666667,
#  'dxpe': 1.2300782778864978,
#  'dxtr': -78.48101265822784,
#  'dxyn': -72.76264591439688,
#  'dynt': 158.9285714285714,
#  'dysl': -16.26506024096386,
#  'dzsi': 368.7022900763359,
#  'ea': 75.7486259160215,
#  'ebay': 13.438735620511721,
#  'ebix': 112.75128294479042,
#  'ebtc': 118.9032258064516,
#  'ecol': 146.11261126005363,
#  'ecpg': 144.47078199052132,
#  'edap': -58.879999999999995,
#  'edgw': 22.950819672131153,
#  'educ': 11.0344827586207,
#  'eeft': 183.3779364548495,
#  'eei': -0.6421744886718845,
#  'efii': 86.32445911111056,
#  'efsc': 23.787872727272724,
#  'egan': 10.68702290076335,
#  'egbn': 227.2673735641686,
#  'eght': 1177.7777777777778,
#  'egle': -70.05781385278132,
#  'egt': -27.149321266968318,
#  'ehth': -46.41975308641976,
#  'elgx': 84.61538461538464,
#  'elon': -25.0936329588015,
#  'elos': -59.3600603398286,
#  'else': -24.091778202676867,
#  'eltk': -83.75,
#  'emcf': 0.8928571428571428,
#  'emci': -19.912661423949373,
#  'emitf': -89.91795619621602,
#  'emkr': 54.95495495495495,
#  'eml': 31.457812350783243,
#  'emms': -73.35722819593786,
#  'endp': -61.086956521739125,
#  'eng': -77.34375,
#  'entg': 109.63302752293578,
#  'epay': 90.95651304347825,
#  'eqfn': -12.76595744680851,
#  'eqix': 430.2763289473685,
#  'eric': -84.49236733704872,
#  'esbk': -29.917115753580397,
#  'esca': 21.521335807050097,
#  'esgr': 93.56846693841355,
#  'esio': -68.87351778656125,
#  'eslt': 235.004367968395,
#  'esnd': -69.19804165913813,
#  'esrx': -6.2042823240213005,
#  'essa': 21.250000000000004,
#  'esxb': 8.391608391608386,
#  'etfc': 49.69027433628318,
#  'evbs': -53.022222222222226,
#  'evep': -93.40425531914893,
#  'evlv': -89.81132075471699,
#  'evol': 306.7796610169492,
#  'ewbc': 42.515477138000094,
#  'exac': 84.33988764044943,
#  'exas': 735.0876842105263,
#  'exel': 130.16217297297297,
#  'exfo': -16.370106761565832,
#  'exls': 119.99047328198822,
#  'expd': 36.202282124914134,
#  'expe': 521.8511556226697,
#  'expo': 217.06009211695775,
#  'extr': 71.02137767220903,
#  'ezpw': -50.0,
#  'falc': -96.31760644418873,
#  'farm': 66.43324929971988,
#  'faro': 34.312918046357616,
#  'fast': 26.65928926991152,
#  'fbiz': 15.391539846603944,
#  'fbms': -7.768595041322318,
#  'fbnc': 31.981766196730472,
#  'fbss': -32.79245660377358,
#  'fcap': 77.56755675675674,
#  'fcco': 18.914081145584714,
#  'fccy': -8.928543549554135,
#  'fcnca': 60.73183983315522,
#  'fdef': 73.52066776859503,
#  'feim': -7.93515358361776,
#  'fele': -17.023345641114958,
#  'ffbc': 58.193795346518854,
#  'ffhl': -82.81157708210277,
#  'ffic': 46.894944863609986,
#  'ffin': -9.69577457023506,
#  'ffiv': 85.20838968151428,
#  'ffkt': 12.121199877564216,
#  'fhco': -37.01298701298701,
#  'finl': 3.448275862068954,
#  'fisi': 37.77490134648982,
#  'fisv': 123.46957352773799,
#  'fizz': 522.9077714249806,
#  'flex': 38.76843018213357,
#  'flic': -40.05480566464502,
#  'flir': 10.496543054682578,
#  'fll': -37.4025974025974,
#  'flws': 62.35864297253635,
#  'flxs': 319.24921725239614,
#  'fmbi': -41.05017847904811}

# %%
# Now, we can find the most profitable company in the period

profitable = max(transformed3, key=transformed3.get)
print(profitable)
print(transformed3[profitable])
# Out:
# admp
# 7483.8389225948395

# %% [markdown]
# It can be seen that the most profitable company to invest on those period is Adamis Pharmaceuticals Corporation, with around 7500 percentage increase in value.
